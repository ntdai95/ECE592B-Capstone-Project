# %% [markdown]
# # Data Preparation & Initialization

# %% [markdown]
# ### Set Gobal Seed

# %%
Seed = 1

# %% [markdown]
# ### Import Data

# %%
import pandas as pd

df = pd.read_csv("packet-data/for_data.csv")

df.head()
# Out:
#    average_p  channel_10_count  channel_10_mean  channel_10_var  \
# 0  -0.860521         -1.583750        -0.842800        0.770734
# 1  -0.624307         -0.267315        -0.762879       -0.361961
# 2  -0.988567         -0.810731        -0.436235        0.300095
# 3  -0.432299         -0.195494        -0.885616       -1.022598
# 4  -0.967851          0.188032        -0.835100       -1.149712
#
#    channel_1_count  channel_1_mean  channel_1_var  channel_30_count  \
# 0        -1.315677       -0.811806      -1.432881         -1.829250
# 1        -0.342127       -0.750525      -0.065298          0.137678
# 2        -0.722586       -0.442007       0.569104         -0.593623
# 3        -1.053230       -0.784335      -0.055243         -0.039735
# 4        -0.418365       -0.797316      -0.482272          0.042701
#
#    channel_30_mean  channel_30_var  ...  stream_max_uri_special_chars  \
# 0        -0.842158        0.785753  ...                     -0.080546
# 1        -0.774956       -0.462472  ...                     -0.080546
# 2        -0.439821        0.272999  ...                     -0.080546
# 3        -0.866857       -0.444237  ...                     -0.021111
# 4        -0.832494       -1.139550  ...                     -0.080546
#
#    stream_rate_5     sum_p  tcp_window_size  \
# 0      -1.197095 -0.779203        -1.438022
# 1      -0.476420 -0.557618         0.907199
# 2      -0.943591 -0.900090         0.288550
# 3      -0.094468 -0.378518        -1.438022
# 4       0.128531 -0.880488        -1.438022
#
#    time_since_previously_displayed_frame       ttl  uri_special_chars  \
# 0                               0.011002 -0.528681          -0.060218
# 1                               0.002179 -0.577999          -0.060218
# 2                              -0.011856 -0.528681          -0.060218
# 3                              -0.011866 -1.317776          -0.060218
# 4                               0.030809 -0.528681          -0.060218
#
#       var_p  id   label
# 0 -0.804974   0  benign
# 1 -0.640341   1  benign
# 2 -0.671684   2  benign
# 3 -0.042268   4  benign
# 4 -1.256204   5  benign
#
# [5 rows x 111 columns]

# %% [markdown]
# ### Drop Variables Not Used
# - Drop "id" column

# %%
# Preserve IDs for linking Phase 2 alerts to Phase 3 flow records.
packet_ids = df["id"].copy() if "id" in df.columns else pd.Series(df.index)

# ID is an identifier, not a behavioral feature.
df = df.drop(columns=["id"], errors="ignore")

df.head()
# Out:
#    average_p  channel_10_count  channel_10_mean  channel_10_var  \
# 0  -0.860521         -1.583750        -0.842800        0.770734
# 1  -0.624307         -0.267315        -0.762879       -0.361961
# 2  -0.988567         -0.810731        -0.436235        0.300095
# 3  -0.432299         -0.195494        -0.885616       -1.022598
# 4  -0.967851          0.188032        -0.835100       -1.149712
#
#    channel_1_count  channel_1_mean  channel_1_var  channel_30_count  \
# 0        -1.315677       -0.811806      -1.432881         -1.829250
# 1        -0.342127       -0.750525      -0.065298          0.137678
# 2        -0.722586       -0.442007       0.569104         -0.593623
# 3        -1.053230       -0.784335      -0.055243         -0.039735
# 4        -0.418365       -0.797316      -0.482272          0.042701
#
#    channel_30_mean  channel_30_var  ...  stream_max_uri_length  \
# 0        -0.842158        0.785753  ...              -0.174817
# 1        -0.774956       -0.462472  ...              -0.174817
# 2        -0.439821        0.272999  ...              -0.174817
# 3        -0.866857       -0.444237  ...               0.816033
# 4        -0.832494       -1.139550  ...              -0.174817
#
#    stream_max_uri_special_chars  stream_rate_5     sum_p  tcp_window_size  \
# 0                     -0.080546      -1.197095 -0.779203        -1.438022
# 1                     -0.080546      -0.476420 -0.557618         0.907199
# 2                     -0.080546      -0.943591 -0.900090         0.288550
# 3                     -0.021111      -0.094468 -0.378518        -1.438022
# 4                     -0.080546       0.128531 -0.880488        -1.438022
#
#    time_since_previously_displayed_frame       ttl  uri_special_chars  \
# 0                               0.011002 -0.528681          -0.060218
# 1                               0.002179 -0.577999          -0.060218
# 2                              -0.011856 -0.528681          -0.060218
# 3                              -0.011866 -1.317776          -0.060218
# 4                               0.030809 -0.528681          -0.060218
#
#       var_p   label
# 0 -0.804974  benign
# 1 -0.640341  benign
# 2 -0.671684  benign
# 3 -0.042268  benign
# 4 -1.256204  benign
#
# [5 rows x 110 columns]

# %% [markdown]
# ### Create Data Matrix and Label Vector

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Separate labels for stratification and evaluation; labels are never passed to fit().
X = df.drop(columns=["label"]).to_numpy()
y = df["label"].to_numpy()

print("Data matrix shape:", X.shape)
print("Label vector shape:", y.shape)

row_indices = np.arange(X.shape[0])
X_train, X_remaining, y_train, y_remaining, index_train, index_remaining = train_test_split(
    X, y, row_indices, test_size=0.4, stratify=y, random_state=Seed
)
X_validation, X_test, y_validation, y_test, index_validation, index_test = train_test_split(
    X_remaining,
    y_remaining,
    index_remaining,
    test_size=0.5,
    stratify=y_remaining,
    random_state=Seed,
)

# Fit preprocessing only on the training partition.
phase2_scaler = StandardScaler()
X_train_scaled = phase2_scaler.fit_transform(X_train)
X_validation_scaled = phase2_scaler.transform(X_validation)
X_test_scaled = phase2_scaler.transform(X_test)

print("Train/validation/test sizes:", X_train.shape[0], X_validation.shape[0], X_test.shape[0])
print("Training labels are retained only for analysis, not model fitting.")
# Out:
# Data matrix shape: (195940, 109)
# Label vector shape: (195940,)
# Train/validation/test sizes: 117564 39188 39188
# Training labels are retained only for analysis, not model fitting.

# %% [markdown]
# # K-means (high-recall alert generator)

# %% [markdown]
# ### K-means Hyperparameters Tuning
# - Hyperparameters:
#     - K: number of clusters used to represent benign behaviour
#     - Threshold_percentile: distance cutoff for classifying a sample as anomalous
#
# - Model selection uses validation results
#     - recall >= 0.8 and FPR <= 0.1
#     - if non qualify
#     - keep configuration with FPR <= 0.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (precision_score, recall_score, f1_score, confusion_matrix,
                             roc_auc_score, average_precision_score)

k_values = [2, 4, 6, 8, 10, 15, 20]
threshold_percentiles = [80, 85, 90, 92, 95, 97, 99]

# Fit K-means on unlabeled training features; labels are used only for validation.
X_kmeans_train = X_train_scaled
X_evaluation = X_validation_scaled
y_evaluation = y_validation
y_attack = y_validation[y_validation != "benign"]
true_attack = y_evaluation != "benign"

models = {}
thresholds = {}
inertias = []
kmeans_results = []

for k in k_values:
    model = KMeans(
        n_clusters=k,
        init="k-means++",
        n_init=5,
        random_state=Seed,
    )
    model.fit(X_kmeans_train)

    # A sample is anomalous when its nearest-centroid distance exceeds
    # the chosen percentile of benign training distances.
    training_distances = model.transform(X_kmeans_train).min(axis=1)
    evaluation_distances = model.transform(X_evaluation).min(axis=1)

    models[k] = model
    inertias.append(model.inertia_)

    for percentile in threshold_percentiles:
        threshold = np.percentile(training_distances, percentile)
        predicted_attack = evaluation_distances > threshold

        precision = precision_score(true_attack, predicted_attack, zero_division=0)
        recall = recall_score(true_attack, predicted_attack, zero_division=0)
        f1 = f1_score(true_attack, predicted_attack, zero_division=0)
        tn, fp, fn, tp = confusion_matrix(
            true_attack, predicted_attack, labels=[False, True]
        ).ravel()
        fpr = fp / (fp + tn) if (fp + tn) else 0.0
        fnr = fn / (fn + tp) if (fn + tp) else 0.0

        thresholds[(k, percentile)] = threshold
        kmeans_results.append({
            "k": k,
            "threshold_percentile": percentile,
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "fpr": fpr,
            "fnr": fnr,
        })

        print(
            f"k={k}, percentile={percentile}: Precision={precision:.4f}, "
            f"Recall={recall:.4f}, F1={f1:.4f}"
        )
        print("  Confusion matrix [[TP, FP], [FN, TN]]:")
        print("  Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]")
        print(np.array([[tp, fp], [fn, tn]]))
        for attack in sorted(np.unique(y_attack)):
            attack_mask = y_evaluation == attack
            detection_rate = predicted_attack[attack_mask].mean()
            print(f"  {attack} detection rate: {detection_rate:.4f}")

kmeans_results_df = pd.DataFrame(kmeans_results)
display(
    kmeans_results_df.sort_values("fnr", ascending=True).reset_index(drop=True)
)

# Prefer high recall for Phase 2, while limiting validation false alarms.
eligible_kmeans = kmeans_results_df[
    (kmeans_results_df["recall"] >= 0.90) & (kmeans_results_df["fpr"] <= 0.15)
]
if eligible_kmeans.empty:
    eligible_kmeans = kmeans_results_df[kmeans_results_df["fpr"] <= 0.15]
if eligible_kmeans.empty:
    eligible_kmeans = kmeans_results_df
best_kmeans_config = eligible_kmeans.sort_values(
    ["fnr", "fpr", "f1"], ascending=[True, True, False]
).iloc[0]

best_k = int(best_kmeans_config["k"])
best_kmeans_percentile = int(best_kmeans_config["threshold_percentile"])
best_kmeans_model = models[best_k]
best_kmeans_threshold = thresholds[(best_k, best_kmeans_percentile)]
kmeans_test_scores = best_kmeans_model.transform(X_test_scaled).min(axis=1)
kmeans_test_predictions = kmeans_test_scores > best_kmeans_threshold
kmeans_test_truth = y_test != "benign"
kmeans_test_precision = precision_score(kmeans_test_truth, kmeans_test_predictions, zero_division=0)
kmeans_test_recall = recall_score(kmeans_test_truth, kmeans_test_predictions, zero_division=0)
kmeans_test_f1 = f1_score(kmeans_test_truth, kmeans_test_predictions, zero_division=0)
kmeans_tn, kmeans_fp, kmeans_fn, kmeans_tp = confusion_matrix(
    kmeans_test_truth, kmeans_test_predictions, labels=[False, True]
).ravel()
kmeans_test_fpr = kmeans_fp / (kmeans_fp + kmeans_tn)
kmeans_test_fnr = kmeans_fn / (kmeans_fn + kmeans_tp)
kmeans_test_roc_auc = roc_auc_score(kmeans_test_truth, kmeans_test_scores)
kmeans_test_pr_auc = average_precision_score(kmeans_test_truth, kmeans_test_scores)
print(
    f"Final K-means test: k={best_k}, percentile={best_kmeans_percentile}, "
    f"Precision={kmeans_test_precision:.4f}, Recall={kmeans_test_recall:.4f}, "
    f"F1={kmeans_test_f1:.4f}, FPR={kmeans_test_fpr:.4f}, "
    f"FNR={kmeans_test_fnr:.4f}, ROC-AUC={kmeans_test_roc_auc:.4f}, "
    f"PR-AUC={kmeans_test_pr_auc:.4f}"
)
print(np.array([[kmeans_tp, kmeans_fp], [kmeans_fn, kmeans_tn]]))
for attack in sorted(np.unique(y_test[y_test != "benign"])):
    attack_mask = y_test == attack
    print(f"  {attack} detection rate: {kmeans_test_predictions[attack_mask].mean():.4f}")

kmeans_alerts_df = pd.DataFrame({
    "packet_id": packet_ids.iloc[index_test].to_numpy(),
    "true_label": y_test,
    "anomaly_score": kmeans_test_scores,
    "alert": kmeans_test_predictions,
})
kmeans_alerts_df = kmeans_alerts_df[kmeans_alerts_df["alert"]].reset_index(drop=True)
# Out:
# k=2, percentile=80: Precision=0.0795, Recall=0.5362, F1=0.1384
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  637  7378]
#  [  551 30622]]
#   brute_force detection rate: 0.2236
#   ddos detection rate: 0.9789
#   dns_spoofing detection rate: 0.2605
#   dos detection rate: 0.8571
#   xss detection rate: 0.3613
# k=2, percentile=85: Precision=0.0965, Recall=0.4899, F1=0.1612
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  582  5450]
#  [  606 32550]]
#   brute_force detection rate: 0.2110
#   ddos detection rate: 0.9494
#   dns_spoofing detection rate: 0.1765
#   dos detection rate: 0.7647
#   xss detection rate: 0.3487
# k=2, percentile=90: Precision=0.1334, Recall=0.4529, F1=0.2061
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  538  3495]
#  [  650 34505]]
#   brute_force detection rate: 0.2025
#   ddos detection rate: 0.8987
#   dns_spoofing detection rate: 0.1471
#   dos detection rate: 0.6723
#   xss detection rate: 0.3445
# k=2, percentile=92: Precision=0.1528, Recall=0.4167, F1=0.2236
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  495  2744]
#  [  693 35256]]
#   brute_force detection rate: 0.1983
#   ddos detection rate: 0.8312
#   dns_spoofing detection rate: 0.1134
#   dos detection rate: 0.6008
#   xss detection rate: 0.3403
# k=2, percentile=95: Precision=0.2102, Recall=0.3434, F1=0.2608
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  408  1533]
#  [  780 36467]]
#   brute_force detection rate: 0.1688
#   ddos detection rate: 0.6456
#   dns_spoofing detection rate: 0.0840
#   dos detection rate: 0.5294
#   xss detection rate: 0.2899
# k=2, percentile=97: Precision=0.2346, Recall=0.2273, F1=0.2309
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  270   881]
#  [  918 37119]]
#   brute_force detection rate: 0.1350
#   ddos detection rate: 0.3333
#   dns_spoofing detection rate: 0.0252
#   dos detection rate: 0.4076
#   xss detection rate: 0.2353
# k=2, percentile=99: Precision=0.1333, Recall=0.0438, F1=0.0659
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   52   338]
#  [ 1136 37662]]
#   brute_force detection rate: 0.0506
#   ddos detection rate: 0.0000
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.0000
#   xss detection rate: 0.1597
# k=4, percentile=80: Precision=0.0871, Recall=0.5842, F1=0.1517
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  694  7270]
#  [  494 30730]]
#   brute_force detection rate: 0.3165
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.2983
#   dos detection rate: 0.9538
#   xss detection rate: 0.3571
# k=4, percentile=85: Precision=0.1090, Recall=0.5488, F1=0.1819
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  652  5328]
#  [  536 32672]]
#   brute_force detection rate: 0.2405
#   ddos detection rate: 0.9916
#   dns_spoofing detection rate: 0.2479
#   dos detection rate: 0.9160
#   xss detection rate: 0.3487
# k=4, percentile=90: Precision=0.1440, Recall=0.4857, F1=0.2221
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  577  3430]
#  [  611 34570]]
#   brute_force detection rate: 0.2025
#   ddos detection rate: 0.9451
#   dns_spoofing detection rate: 0.1597
#   dos detection rate: 0.7731
#   xss detection rate: 0.3487
# k=4, percentile=92: Precision=0.1678, Recall=0.4512, F1=0.2446
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  536  2659]
#  [  652 35341]]
#   brute_force detection rate: 0.2025
#   ddos detection rate: 0.9030
#   dns_spoofing detection rate: 0.1345
#   dos detection rate: 0.6723
#   xss detection rate: 0.3445
# k=4, percentile=95: Precision=0.2031, Recall=0.3375, F1=0.2536
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  401  1573]
#  [  787 36427]]
#   brute_force detection rate: 0.1772
#   ddos detection rate: 0.6582
#   dns_spoofing detection rate: 0.0504
#   dos detection rate: 0.5168
#   xss detection rate: 0.2857
# k=4, percentile=97: Precision=0.2463, Recall=0.2374, F1=0.2417
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  282   863]
#  [  906 37137]]
#   brute_force detection rate: 0.1477
#   ddos detection rate: 0.4093
#   dns_spoofing detection rate: 0.0294
#   dos detection rate: 0.3824
#   xss detection rate: 0.2185
# k=4, percentile=99: Precision=0.1333, Recall=0.0438, F1=0.0659
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   52   338]
#  [ 1136 37662]]
#   brute_force detection rate: 0.0506
#   ddos detection rate: 0.0000
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.0000
#   xss detection rate: 0.1597
# k=6, percentile=80: Precision=0.0882, Recall=0.5901, F1=0.1535
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  701  7247]
#  [  487 30753]]
#   brute_force detection rate: 0.2068
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.3866
#   dos detection rate: 0.9958
#   xss detection rate: 0.3613
# k=6, percentile=85: Precision=0.1145, Recall=0.5699, F1=0.1906
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  677  5238]
#  [  511 32762]]
#   brute_force detection rate: 0.1814
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.3361
#   dos detection rate: 0.9916
#   xss detection rate: 0.3445
# k=6, percentile=90: Precision=0.1586, Recall=0.5286, F1=0.2440
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  628  3331]
#  [  560 34669]]
#   brute_force detection rate: 0.1392
#   ddos detection rate: 0.9873
#   dns_spoofing detection rate: 0.2227
#   dos detection rate: 0.9538
#   xss detection rate: 0.3403
# k=6, percentile=92: Precision=0.1864, Recall=0.5025, F1=0.2719
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  597  2606]
#  [  591 35394]]
#   brute_force detection rate: 0.1266
#   ddos detection rate: 0.9747
#   dns_spoofing detection rate: 0.1681
#   dos detection rate: 0.9034
#   xss detection rate: 0.3403
# k=6, percentile=95: Precision=0.2437, Recall=0.4074, F1=0.3050
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  484  1502]
#  [  704 36498]]
#   brute_force detection rate: 0.0675
#   ddos detection rate: 0.8903
#   dns_spoofing detection rate: 0.0924
#   dos detection rate: 0.6891
#   xss detection rate: 0.2983
# k=6, percentile=97: Precision=0.3160, Recall=0.3123, F1=0.3141
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  371   803]
#  [  817 37197]]
#   brute_force detection rate: 0.0675
#   ddos detection rate: 0.6793
#   dns_spoofing detection rate: 0.0294
#   dos detection rate: 0.5336
#   xss detection rate: 0.2521
# k=6, percentile=99: Precision=0.1292, Recall=0.0421, F1=0.0635
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   50   337]
#  [ 1138 37663]]
#   brute_force detection rate: 0.0422
#   ddos detection rate: 0.0000
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.0000
#   xss detection rate: 0.1597
# k=8, percentile=80: Precision=0.0881, Recall=0.5892, F1=0.1532
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  700  7248]
#  [  488 30752]]
#   brute_force detection rate: 0.2152
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.3782
#   dos detection rate: 0.9958
#   xss detection rate: 0.3571
# k=8, percentile=85: Precision=0.1134, Recall=0.5682, F1=0.1890
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  675  5279]
#  [  513 32721]]
#   brute_force detection rate: 0.2068
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.3067
#   dos detection rate: 0.9958
#   xss detection rate: 0.3319
# k=8, percentile=90: Precision=0.1587, Recall=0.5269, F1=0.2440
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  626  3318]
#  [  562 34682]]
#   brute_force detection rate: 0.1477
#   ddos detection rate: 0.9873
#   dns_spoofing detection rate: 0.2059
#   dos detection rate: 0.9706
#   xss detection rate: 0.3235
# k=8, percentile=92: Precision=0.1897, Recall=0.5093, F1=0.2764
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  605  2584]
#  [  583 35416]]
#   brute_force detection rate: 0.1224
#   ddos detection rate: 0.9831
#   dns_spoofing detection rate: 0.1765
#   dos detection rate: 0.9412
#   xss detection rate: 0.3235
# k=8, percentile=95: Precision=0.2402, Recall=0.4024, F1=0.3008
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  478  1512]
#  [  710 36488]]
#   brute_force detection rate: 0.0380
#   ddos detection rate: 0.8439
#   dns_spoofing detection rate: 0.0756
#   dos detection rate: 0.7647
#   xss detection rate: 0.2899
# k=8, percentile=97: Precision=0.2788, Recall=0.2753, F1=0.2770
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  327   846]
#  [  861 37154]]
#   brute_force detection rate: 0.0127
#   ddos detection rate: 0.5443
#   dns_spoofing detection rate: 0.0336
#   dos detection rate: 0.5546
#   xss detection rate: 0.2311
# k=8, percentile=99: Precision=0.1172, Recall=0.0379, F1=0.0573
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   45   339]
#  [ 1143 37661]]
#   brute_force detection rate: 0.0084
#   ddos detection rate: 0.0169
#   dns_spoofing detection rate: 0.0042
#   dos detection rate: 0.0168
#   xss detection rate: 0.1429
# k=10, percentile=80: Precision=0.0925, Recall=0.6153, F1=0.1609
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  731  7169]
#  [  457 30831]]
#   brute_force detection rate: 0.2658
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.4286
#   dos detection rate: 1.0000
#   xss detection rate: 0.3824
# k=10, percentile=85: Precision=0.1180, Recall=0.5825, F1=0.1963
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  692  5171]
#  [  496 32829]]
#   brute_force detection rate: 0.2025
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.3613
#   dos detection rate: 0.9958
#   xss detection rate: 0.3529
# k=10, percentile=90: Precision=0.1692, Recall=0.5547, F1=0.2593
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  659  3236]
#  [  529 34764]]
#   brute_force detection rate: 0.1646
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.2773
#   dos detection rate: 0.9916
#   xss detection rate: 0.3445
# k=10, percentile=92: Precision=0.2004, Recall=0.5303, F1=0.2909
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  630  2513]
#  [  558 35487]]
#   brute_force detection rate: 0.1350
#   ddos detection rate: 0.9873
#   dns_spoofing detection rate: 0.2185
#   dos detection rate: 0.9706
#   xss detection rate: 0.3403
# k=10, percentile=95: Precision=0.2891, Recall=0.4781, F1=0.3603
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  568  1397]
#  [  620 36603]]
#   brute_force detection rate: 0.1055
#   ddos detection rate: 0.9283
#   dns_spoofing detection rate: 0.1513
#   dos detection rate: 0.8655
#   xss detection rate: 0.3403
# k=10, percentile=97: Precision=0.3612, Recall=0.3493, F1=0.3552
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  415   734]
#  [  773 37266]]
#   brute_force detection rate: 0.0675
#   ddos detection rate: 0.6667
#   dns_spoofing detection rate: 0.0630
#   dos detection rate: 0.6513
#   xss detection rate: 0.2983
# k=10, percentile=99: Precision=0.1698, Recall=0.0539, F1=0.0818
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   64   313]
#  [ 1124 37687]]
#   brute_force detection rate: 0.0422
#   ddos detection rate: 0.0338
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.0252
#   xss detection rate: 0.1597
# k=15, percentile=80: Precision=0.0927, Recall=0.6178, F1=0.1612
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  734  7182]
#  [  454 30818]]
#   brute_force detection rate: 0.2911
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.4034
#   dos detection rate: 1.0000
#   xss detection rate: 0.3992
# k=15, percentile=85: Precision=0.1143, Recall=0.5707, F1=0.1904
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  678  5256]
#  [  510 32744]]
#   brute_force detection rate: 0.2025
#   ddos detection rate: 0.9916
#   dns_spoofing detection rate: 0.2941
#   dos detection rate: 1.0000
#   xss detection rate: 0.3655
# k=15, percentile=90: Precision=0.1611, Recall=0.5438, F1=0.2485
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  646  3365]
#  [  542 34635]]
#   brute_force detection rate: 0.1646
#   ddos detection rate: 0.9789
#   dns_spoofing detection rate: 0.2437
#   dos detection rate: 0.9916
#   xss detection rate: 0.3403
# k=15, percentile=92: Precision=0.1941, Recall=0.5152, F1=0.2820
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  612  2541]
#  [  576 35459]]
#   brute_force detection rate: 0.1350
#   ddos detection rate: 0.9325
#   dns_spoofing detection rate: 0.1975
#   dos detection rate: 0.9706
#   xss detection rate: 0.3403
# k=15, percentile=95: Precision=0.2730, Recall=0.4571, F1=0.3418
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  543  1446]
#  [  645 36554]]
#   brute_force detection rate: 0.1013
#   ddos detection rate: 0.8439
#   dns_spoofing detection rate: 0.1345
#   dos detection rate: 0.8655
#   xss detection rate: 0.3403
# k=15, percentile=97: Precision=0.3471, Recall=0.3316, F1=0.3392
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  394   741]
#  [  794 37259]]
#   brute_force detection rate: 0.0675
#   ddos detection rate: 0.5485
#   dns_spoofing detection rate: 0.0588
#   dos detection rate: 0.6723
#   xss detection rate: 0.3109
# k=15, percentile=99: Precision=0.2874, Recall=0.1002, F1=0.1486
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  119   295]
#  [ 1069 37705]]
#   brute_force detection rate: 0.0464
#   ddos detection rate: 0.1139
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.1723
#   xss detection rate: 0.1597
# k=20, percentile=80: Precision=0.0909, Recall=0.6002, F1=0.1578
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  713  7133]
#  [  475 30867]]
#   brute_force detection rate: 0.3038
#   ddos detection rate: 0.9367
#   dns_spoofing detection rate: 0.4958
#   dos detection rate: 0.8277
#   xss detection rate: 0.4370
# k=20, percentile=85: Precision=0.1034, Recall=0.5109, F1=0.1720
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  607  5262]
#  [  581 32738]]
#   brute_force detection rate: 0.2405
#   ddos detection rate: 0.8101
#   dns_spoofing detection rate: 0.3866
#   dos detection rate: 0.7311
#   xss detection rate: 0.3866
# k=20, percentile=90: Precision=0.1224, Recall=0.4108, F1=0.1886
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  488  3498]
#  [  700 34502]]
#   brute_force detection rate: 0.2025
#   ddos detection rate: 0.6456
#   dns_spoofing detection rate: 0.2899
#   dos detection rate: 0.5672
#   xss detection rate: 0.3487
# k=20, percentile=92: Precision=0.1353, Recall=0.3586, F1=0.1965
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  426  2722]
#  [  762 35278]]
#   brute_force detection rate: 0.1857
#   ddos detection rate: 0.5443
#   dns_spoofing detection rate: 0.2479
#   dos detection rate: 0.4790
#   xss detection rate: 0.3361
# k=20, percentile=95: Precision=0.1477, Recall=0.2449, F1=0.1843
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  291  1679]
#  [  897 36321]]
#   brute_force detection rate: 0.1350
#   ddos detection rate: 0.3080
#   dns_spoofing detection rate: 0.1933
#   dos detection rate: 0.2647
#   xss detection rate: 0.3235
# k=20, percentile=97: Precision=0.1681, Recall=0.1641, F1=0.1661
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  195   965]
#  [  993 37035]]
#   brute_force detection rate: 0.0759
#   ddos detection rate: 0.1772
#   dns_spoofing detection rate: 0.1218
#   dos detection rate: 0.1303
#   xss detection rate: 0.3151
# k=20, percentile=99: Precision=0.1373, Recall=0.0446, F1=0.0673
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   53   333]
#  [ 1135 37667]]
#   brute_force detection rate: 0.0127
#   ddos detection rate: 0.0211
#   dns_spoofing detection rate: 0.0210
#   dos detection rate: 0.0000
#   xss detection rate: 0.1681
#      k  threshold_percentile  precision    recall        f1       fpr  \
# 0   15                    80   0.092724  0.617845  0.161248  0.189000
# 1   10                    80   0.092532  0.615320  0.160871  0.188658
# 2   20                    80   0.090874  0.600168  0.157848  0.187711
# 3    6                    80   0.088198  0.590067  0.153459  0.190711
# 4    8                    80   0.088072  0.589226  0.153240  0.190737
# 5    4                    80   0.087142  0.584175  0.151661  0.191316
# 6   10                    85   0.118028  0.582492  0.196284  0.136079
# 7   15                    85   0.114257  0.570707  0.190396  0.138316
# 8    6                    85   0.114455  0.569865  0.190624  0.137842
# 9    8                    85   0.113369  0.568182  0.189023  0.138921
# 10  10                    90   0.169191  0.554714  0.259296  0.085158
# 11   4                    85   0.109030  0.548822  0.181920  0.140211
# 12  15                    90   0.161057  0.543771  0.248509  0.088553
# 13   2                    80   0.079476  0.536195  0.138433  0.194158
# 14  10                    92   0.200445  0.530303  0.290926  0.066132
# 15   6                    90   0.158626  0.528620  0.244026  0.087658
# 16   8                    90   0.158722  0.526936  0.243959  0.087316
# 17  15                    92   0.194101  0.515152  0.281963  0.066868
# 18  20                    85   0.103425  0.510943  0.172028  0.138474
# 19   8                    92   0.189715  0.509259  0.276445  0.068000
# 20   6                    92   0.186388  0.502525  0.271920  0.068579
# 21   2                    85   0.096485  0.489899  0.161219  0.143421
# 22   4                    90   0.143998  0.485690  0.222137  0.090263
# 23  10                    95   0.289059  0.478114  0.360292  0.036763
# 24  15                    95   0.273002  0.457071  0.341832  0.038053
# 25   2                    90   0.133399  0.452862  0.206091  0.091974
# 26   4                    92   0.167762  0.451178  0.244581  0.069974
# 27   2                    92   0.152825  0.416667  0.223628  0.072211
# 28  20                    90   0.122428  0.410774  0.188635  0.092053
# 29   6                    95   0.243706  0.407407  0.304978  0.039526
# 30   8                    95   0.240201  0.402357  0.300818  0.039789
# 31  20                    92   0.135324  0.358586  0.196494  0.071632
# 32  10                    97   0.361184  0.349327  0.355156  0.019316
# 33   2                    95   0.210201  0.343434  0.260786  0.040342
# 34   4                    95   0.203141  0.337542  0.253637  0.041395
# 35  15                    97   0.347137  0.331650  0.339217  0.019500
# 36   6                    97   0.316014  0.312290  0.314141  0.021132
# 37   8                    97   0.278772  0.275253  0.277001  0.022263
# 38  20                    95   0.147716  0.244949  0.184294  0.044184
# 39   4                    97   0.246288  0.237374  0.241749  0.022711
# 40   2                    97   0.234579  0.227273  0.230868  0.023184
# 41  20                    97   0.168103  0.164141  0.166099  0.025395
# 42  15                    99   0.287440  0.100168  0.148564  0.007763
# 43  10                    99   0.169761  0.053872  0.081789  0.008237
# 44  20                    99   0.137306  0.044613  0.067344  0.008763
# 45   4                    99   0.133333  0.043771  0.065906  0.008895
# 46   2                    99   0.133333  0.043771  0.065906  0.008895
# 47   6                    99   0.129199  0.042088  0.063492  0.008868
# 48   8                    99   0.117188  0.037879  0.057252  0.008921
#
#          fnr
# 0   0.382155
# 1   0.384680
# 2   0.399832
# 3   0.409933
# 4   0.410774
# 5   0.415825
# 6   0.417508
# 7   0.429293
# 8   0.430135
# 9   0.431818
# 10  0.445286
# 11  0.451178
# 12  0.456229
# 13  0.463805
# 14  0.469697
# 15  0.471380
# 16  0.473064
# 17  0.484848
# 18  0.489057
# 19  0.490741
# 20  0.497475
# 21  0.510101
# 22  0.514310
# 23  0.521886
# 24  0.542929
# 25  0.547138
# 26  0.548822
# 27  0.583333
# 28  0.589226
# 29  0.592593
# 30  0.597643
# 31  0.641414
# 32  0.650673
# 33  0.656566
# 34  0.662458
# 35  0.668350
# 36  0.687710
# 37  0.724747
# 38  0.755051
# 39  0.762626
# 40  0.772727
# 41  0.835859
# 42  0.899832
# 43  0.946128
# 44  0.955387
# 45  0.956229
# 46  0.956229
# 47  0.957912
# 48  0.962121
# Final K-means test: k=10, percentile=85, Precision=0.1183, Recall=0.6010, F1=0.1976, FPR=0.1401, FNR=0.3990, ROC-AUC=0.8010, PR-AUC=0.1906
# [[  714  5323]
#  [  474 32677]]
#   brute_force detection rate: 0.2059
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.4177
#   dos detection rate: 1.0000
#   xss detection rate: 0.3797

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 9))
axes = axes.ravel()

# Plot inertia to show how well the model fits the benign training data.
axes[0].plot(k_values, inertias, marker="o")
axes[0].set(title="Benign Training Inertia", xlabel="k", ylabel="Inertia")
axes[0].grid(alpha=0.3)

# Plot each metric for every threshold percentile.
for axis, metric, title in zip(
    axes[1:],
    ["precision", "recall", "f1", "fpr", "fnr"],
    ["Precision", "Recall", "F1 Score", "False Positive Rate", "False Negative Rate"],
):
    for percentile in threshold_percentiles:
        subset = kmeans_results_df[
            kmeans_results_df["threshold_percentile"] == percentile
        ].sort_values("k")
        axis.plot(
            subset["k"], subset[metric], marker="o", label=f"Percentile {percentile}"
        )
    axis.set(title=title, xlabel="k", ylabel="Score")
    axis.set_xticks(k_values)
    axis.grid(alpha=0.3)
    axis.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Autoencoders (high-recall alert generator)

# %% [markdown]
# ### Autoencoders Hyperparameters Tuning

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (precision_score, recall_score, f1_score, confusion_matrix,
                             roc_auc_score, average_precision_score)

keras.utils.set_random_seed(Seed)

bottleneck_sizes = [2, 4, 8, 16, 32]
threshold_percentiles = [80, 85, 90, 92, 95, 97, 99]

# Fit the autoencoder on unlabeled training features.
X_benign_train_ae = X_train_scaled.astype(np.float32)
X_evaluation_ae = X_validation_scaled.astype(np.float32)
y_evaluation_ae = y_validation
y_attack_ae = y_validation[y_validation != "benign"]
true_attack_ae = y_evaluation_ae != "benign"

input_dim = X_benign_train_ae.shape[1]
autoencoder_models = {}
ae_results = []

for bottleneck_size in bottleneck_sizes:
    keras.backend.clear_session()
    keras.utils.set_random_seed(Seed)

    inputs = keras.Input(shape=(input_dim,))
    encoded = keras.layers.Dense(64, activation="relu")(inputs)
    bottleneck = keras.layers.Dense(
        bottleneck_size, activation="relu", name="bottleneck"
    )(encoded)
    decoded = keras.layers.Dense(64, activation="relu")(bottleneck)
    outputs = keras.layers.Dense(input_dim)(decoded)
    autoencoder = keras.Model(inputs, outputs, name=f"autoencoder_{bottleneck_size}")
    autoencoder.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="mse",
    )

    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=5, restore_best_weights=True
    )
    history = autoencoder.fit(
        X_benign_train_ae,
        X_benign_train_ae,
        epochs=50,
        batch_size=512,
        validation_split=0.1,
        shuffle=True,
        callbacks=[early_stopping],
        verbose=0,
    )
    autoencoder_models[bottleneck_size] = autoencoder
    print(f"Bottleneck {bottleneck_size}: trained for {len(history.history['loss'])} epochs")

    train_reconstruction = autoencoder.predict(X_benign_train_ae, verbose=0)
    train_errors = np.mean(
        (X_benign_train_ae - train_reconstruction) ** 2, axis=1
    )
    evaluation_reconstruction = autoencoder.predict(X_evaluation_ae, verbose=0)
    evaluation_errors = np.mean(
        (X_evaluation_ae - evaluation_reconstruction) ** 2, axis=1
    )

    for percentile in threshold_percentiles:
        threshold = np.percentile(train_errors, percentile)
        predicted_attack = evaluation_errors > threshold

        precision = precision_score(
            true_attack_ae, predicted_attack, zero_division=0
        )
        f1 = f1_score(true_attack_ae, predicted_attack, zero_division=0)
        recall = recall_score(true_attack_ae, predicted_attack, zero_division=0)
        tn, fp, fn, tp = confusion_matrix(
            true_attack_ae, predicted_attack, labels=[False, True]
        ).ravel()
        fpr = fp / (fp + tn) if (fp + tn) else 0.0
        fnr = fn / (fn + tp) if (fn + tp) else 0.0

        result = {
            "bottleneck_size": bottleneck_size,
            "threshold_percentile": percentile,
            "threshold": threshold,
            "precision": precision,
            "f1": f1,
            "recall": recall,
            "fpr": fpr,
            "fnr": fnr,
        }
        ae_results.append(result)

        print(
            f"bottleneck={bottleneck_size}, percentile={percentile}: "
            f"Precision={precision:.4f}, Recall={recall:.4f}, "
            f"F1={f1:.4f}"
        )
        print("  Confusion matrix [[TP, FP], [FN, TN]]:")
        print("  Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]")
        print(np.array([[tp, fp], [fn, tn]]))
        for attack in sorted(np.unique(y_attack_ae)):
            attack_mask = y_evaluation_ae == attack
            detection_rate = predicted_attack[attack_mask].mean()
            print(f"  {attack} detection rate: {detection_rate:.4f}")

ae_results_df = pd.DataFrame(ae_results)
display(
    ae_results_df.sort_values("fnr", ascending=True).reset_index(drop=True)
)

# Select on validation data: prioritize recall, then control false alarms.
eligible_ae = ae_results_df[
    (ae_results_df["recall"] >= 0.90) & (ae_results_df["fpr"] <= 0.15)
]
if eligible_ae.empty:
    eligible_ae = ae_results_df[ae_results_df["fpr"] <= 0.15]
if eligible_ae.empty:
    eligible_ae = ae_results_df
best_ae_config = eligible_ae.sort_values(
    ["fnr", "fpr", "f1"], ascending=[True, True, False]
).iloc[0]
best_bottleneck_size = int(best_ae_config["bottleneck_size"])
best_ae_percentile = int(best_ae_config["threshold_percentile"])
best_autoencoder = autoencoder_models[best_bottleneck_size]
best_ae_threshold = float(best_ae_config["threshold"])

X_test_ae = X_test_scaled.astype(np.float32)
ae_test_reconstruction = best_autoencoder.predict(X_test_ae, verbose=0)
ae_test_scores = np.mean((X_test_ae - ae_test_reconstruction) ** 2, axis=1)
ae_test_predictions = ae_test_scores > best_ae_threshold
ae_test_truth = y_test != "benign"
ae_test_precision = precision_score(ae_test_truth, ae_test_predictions, zero_division=0)
ae_test_recall = recall_score(ae_test_truth, ae_test_predictions, zero_division=0)
ae_test_f1 = f1_score(ae_test_truth, ae_test_predictions, zero_division=0)
ae_tn, ae_fp, ae_fn, ae_tp = confusion_matrix(
    ae_test_truth, ae_test_predictions, labels=[False, True]
).ravel()
ae_test_fpr = ae_fp / (ae_fp + ae_tn)
ae_test_fnr = ae_fn / (ae_fn + ae_tp)
ae_test_roc_auc = roc_auc_score(ae_test_truth, ae_test_scores)
ae_test_pr_auc = average_precision_score(ae_test_truth, ae_test_scores)
print(
    f"Final autoencoder test: bottleneck={best_bottleneck_size}, "
    f"percentile={best_ae_percentile}, Precision={ae_test_precision:.4f}, "
    f"Recall={ae_test_recall:.4f}, F1={ae_test_f1:.4f}, "
    f"FPR={ae_test_fpr:.4f}, FNR={ae_test_fnr:.4f}, "
    f"ROC-AUC={ae_test_roc_auc:.4f}, PR-AUC={ae_test_pr_auc:.4f}"
)
print(np.array([[ae_tp, ae_fp], [ae_fn, ae_tn]]))
for attack in sorted(np.unique(y_test[y_test != "benign"])):
    attack_mask = y_test == attack
    print(f"  {attack} detection rate: {ae_test_predictions[attack_mask].mean():.4f}")

autoencoder_alerts_df = pd.DataFrame({
    "packet_id": packet_ids.iloc[index_test].to_numpy(),
    "true_label": y_test,
    "anomaly_score": ae_test_scores,
    "alert": ae_test_predictions,
})
autoencoder_alerts_df = autoencoder_alerts_df[
    autoencoder_alerts_df["alert"]
].reset_index(drop=True)
# Out:
# Bottleneck 2: trained for 50 epochs
# bottleneck=2, percentile=80: Precision=0.0902, Recall=0.6061, F1=0.1571
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  720  7260]
#  [  468 30740]]
#   brute_force detection rate: 0.2743
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.3319
#   dos detection rate: 1.0000
#   xss detection rate: 0.4286
# bottleneck=2, percentile=85: Precision=0.1148, Recall=0.5724, F1=0.1912
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  680  5245]
#  [  508 32755]]
#   brute_force detection rate: 0.2152
#   ddos detection rate: 0.9873
#   dns_spoofing detection rate: 0.2983
#   dos detection rate: 0.9958
#   xss detection rate: 0.3655
# bottleneck=2, percentile=90: Precision=0.1655, Recall=0.5463, F1=0.2541
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  649  3272]
#  [  539 34728]]
#   brute_force detection rate: 0.1941
#   ddos detection rate: 0.9620
#   dns_spoofing detection rate: 0.2479
#   dos detection rate: 0.9916
#   xss detection rate: 0.3361
# bottleneck=2, percentile=92: Precision=0.1974, Recall=0.5185, F1=0.2860
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  616  2504]
#  [  572 35496]]
#   brute_force detection rate: 0.1730
#   ddos detection rate: 0.9114
#   dns_spoofing detection rate: 0.2143
#   dos detection rate: 0.9580
#   xss detection rate: 0.3361
# bottleneck=2, percentile=95: Precision=0.2674, Recall=0.4453, F1=0.3342
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  529  1449]
#  [  659 36551]]
#   brute_force detection rate: 0.1350
#   ddos detection rate: 0.7553
#   dns_spoofing detection rate: 0.1513
#   dos detection rate: 0.8529
#   xss detection rate: 0.3319
# bottleneck=2, percentile=97: Precision=0.3373, Recall=0.3367, F1=0.3370
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  400   786]
#  [  788 37214]]
#   brute_force detection rate: 0.1013
#   ddos detection rate: 0.5401
#   dns_spoofing detection rate: 0.0714
#   dos detection rate: 0.6681
#   xss detection rate: 0.3025
# bottleneck=2, percentile=99: Precision=0.3067, Recall=0.1002, F1=0.1510
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  119   269]
#  [ 1069 37731]]
#   brute_force detection rate: 0.0295
#   ddos detection rate: 0.0549
#   dns_spoofing detection rate: 0.0126
#   dos detection rate: 0.2605
#   xss detection rate: 0.1429
# Bottleneck 4: trained for 50 epochs
# bottleneck=4, percentile=80: Precision=0.0860, Recall=0.5766, F1=0.1497
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  685  7279]
#  [  503 30721]]
#   brute_force detection rate: 0.3544
#   ddos detection rate: 0.8481
#   dns_spoofing detection rate: 0.3824
#   dos detection rate: 0.8025
#   xss detection rate: 0.4958
# bottleneck=4, percentile=85: Precision=0.0975, Recall=0.4949, F1=0.1629
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  588  5441]
#  [  600 32559]]
#   brute_force detection rate: 0.2954
#   ddos detection rate: 0.7342
#   dns_spoofing detection rate: 0.3109
#   dos detection rate: 0.7227
#   xss detection rate: 0.4118
# bottleneck=4, percentile=90: Precision=0.1140, Recall=0.3813, F1=0.1755
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  453  3521]
#  [  735 34479]]
#   brute_force detection rate: 0.2194
#   ddos detection rate: 0.5443
#   dns_spoofing detection rate: 0.2647
#   dos detection rate: 0.5420
#   xss detection rate: 0.3361
# bottleneck=4, percentile=92: Precision=0.1237, Recall=0.3325, F1=0.1804
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  395  2797]
#  [  793 35203]]
#   brute_force detection rate: 0.1941
#   ddos detection rate: 0.4684
#   dns_spoofing detection rate: 0.2395
#   dos detection rate: 0.4454
#   xss detection rate: 0.3151
# bottleneck=4, percentile=95: Precision=0.1396, Recall=0.2323, F1=0.1744
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  276  1701]
#  [  912 36299]]
#   brute_force detection rate: 0.1308
#   ddos detection rate: 0.2532
#   dns_spoofing detection rate: 0.1681
#   dos detection rate: 0.3235
#   xss detection rate: 0.2857
# bottleneck=4, percentile=97: Precision=0.1523, Recall=0.1507, F1=0.1515
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  179   996]
#  [ 1009 37004]]
#   brute_force detection rate: 0.0717
#   ddos detection rate: 0.1308
#   dns_spoofing detection rate: 0.1345
#   dos detection rate: 0.1849
#   xss detection rate: 0.2311
# bottleneck=4, percentile=99: Precision=0.1906, Recall=0.0614, F1=0.0929
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   73   310]
#  [ 1115 37690]]
#   brute_force detection rate: 0.0253
#   ddos detection rate: 0.0464
#   dns_spoofing detection rate: 0.0588
#   dos detection rate: 0.0630
#   xss detection rate: 0.1134
# Bottleneck 8: trained for 50 epochs
# bottleneck=8, percentile=80: Precision=0.0745, Recall=0.4958, F1=0.1295
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  589  7319]
#  [  599 30681]]
#   brute_force detection rate: 0.2827
#   ddos detection rate: 0.6371
#   dns_spoofing detection rate: 0.3950
#   dos detection rate: 0.6597
#   xss detection rate: 0.5042
# bottleneck=8, percentile=85: Precision=0.0798, Recall=0.3965, F1=0.1329
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  471  5428]
#  [  717 32572]]
#   brute_force detection rate: 0.1772
#   ddos detection rate: 0.5063
#   dns_spoofing detection rate: 0.3445
#   dos detection rate: 0.5462
#   xss detection rate: 0.4076
# bottleneck=8, percentile=90: Precision=0.0872, Recall=0.2929, F1=0.1343
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  348  3645]
#  [  840 34355]]
#   brute_force detection rate: 0.1097
#   ddos detection rate: 0.3544
#   dns_spoofing detection rate: 0.3067
#   dos detection rate: 0.3655
#   xss detection rate: 0.3277
# bottleneck=8, percentile=92: Precision=0.0952, Recall=0.2551, F1=0.1386
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  303  2880]
#  [  885 35120]]
#   brute_force detection rate: 0.0759
#   ddos detection rate: 0.3207
#   dns_spoofing detection rate: 0.2773
#   dos detection rate: 0.3151
#   xss detection rate: 0.2857
# bottleneck=8, percentile=95: Precision=0.1213, Recall=0.2020, F1=0.1516
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  240  1739]
#  [  948 36261]]
#   brute_force detection rate: 0.0506
#   ddos detection rate: 0.2278
#   dns_spoofing detection rate: 0.2437
#   dos detection rate: 0.2479
#   xss detection rate: 0.2395
# bottleneck=8, percentile=97: Precision=0.1406, Recall=0.1414, F1=0.1410
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  168  1027]
#  [ 1020 36973]]
#   brute_force detection rate: 0.0338
#   ddos detection rate: 0.1350
#   dns_spoofing detection rate: 0.1639
#   dos detection rate: 0.1807
#   xss detection rate: 0.1933
# bottleneck=8, percentile=99: Precision=0.1366, Recall=0.0421, F1=0.0644
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   50   316]
#  [ 1138 37684]]
#   brute_force detection rate: 0.0042
#   ddos detection rate: 0.0253
#   dns_spoofing detection rate: 0.0462
#   dos detection rate: 0.0630
#   xss detection rate: 0.0714
# Bottleneck 16: trained for 50 epochs
# bottleneck=16, percentile=80: Precision=0.0847, Recall=0.5589, F1=0.1470
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  664  7179]
#  [  524 30821]]
#   brute_force detection rate: 0.4008
#   ddos detection rate: 0.7046
#   dns_spoofing detection rate: 0.4118
#   dos detection rate: 0.7899
#   xss detection rate: 0.4874
# bottleneck=16, percentile=85: Precision=0.0936, Recall=0.4630, F1=0.1557
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  550  5327]
#  [  638 32673]]
#   brute_force detection rate: 0.2616
#   ddos detection rate: 0.5949
#   dns_spoofing detection rate: 0.3697
#   dos detection rate: 0.6765
#   xss detection rate: 0.4118
# bottleneck=16, percentile=90: Precision=0.1093, Recall=0.3620, F1=0.1679
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  430  3503]
#  [  758 34497]]
#   brute_force detection rate: 0.1435
#   ddos detection rate: 0.4768
#   dns_spoofing detection rate: 0.3151
#   dos detection rate: 0.5420
#   xss detection rate: 0.3319
# bottleneck=16, percentile=92: Precision=0.1206, Recall=0.3224, F1=0.1755
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  383  2794]
#  [  805 35206]]
#   brute_force detection rate: 0.1097
#   ddos detection rate: 0.4177
#   dns_spoofing detection rate: 0.3025
#   dos detection rate: 0.4916
#   xss detection rate: 0.2899
# bottleneck=16, percentile=95: Precision=0.1379, Recall=0.2290, F1=0.1721
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  272  1701]
#  [  916 36299]]
#   brute_force detection rate: 0.0675
#   ddos detection rate: 0.2447
#   dns_spoofing detection rate: 0.2353
#   dos detection rate: 0.3739
#   xss detection rate: 0.2227
# bottleneck=16, percentile=97: Precision=0.1583, Recall=0.1540, F1=0.1561
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  183   973]
#  [ 1005 37027]]
#   brute_force detection rate: 0.0295
#   ddos detection rate: 0.1266
#   dns_spoofing detection rate: 0.1891
#   dos detection rate: 0.2689
#   xss detection rate: 0.1555
# bottleneck=16, percentile=99: Precision=0.1877, Recall=0.0589, F1=0.0897
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   70   303]
#  [ 1118 37697]]
#   brute_force detection rate: 0.0127
#   ddos detection rate: 0.0211
#   dns_spoofing detection rate: 0.0672
#   dos detection rate: 0.1050
#   xss detection rate: 0.0882
# Bottleneck 32: trained for 50 epochs
# bottleneck=32, percentile=80: Precision=0.0904, Recall=0.5875, F1=0.1568
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  698  7019]
#  [  490 30981]]
#   brute_force detection rate: 0.4515
#   ddos detection rate: 0.8186
#   dns_spoofing detection rate: 0.3992
#   dos detection rate: 0.8361
#   xss detection rate: 0.4328
# bottleneck=32, percentile=85: Precision=0.1046, Recall=0.5135, F1=0.1738
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  610  5223]
#  [  578 32777]]
#   brute_force detection rate: 0.2996
#   ddos detection rate: 0.7300
#   dns_spoofing detection rate: 0.3824
#   dos detection rate: 0.7521
#   xss detection rate: 0.4034
# bottleneck=32, percentile=90: Precision=0.1261, Recall=0.4200, F1=0.1940
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  499  3458]
#  [  689 34542]]
#   brute_force detection rate: 0.2068
#   ddos detection rate: 0.6287
#   dns_spoofing detection rate: 0.3361
#   dos detection rate: 0.6261
#   xss detection rate: 0.3025
# bottleneck=32, percentile=92: Precision=0.1429, Recall=0.3822, F1=0.2080
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  454  2723]
#  [  734 35277]]
#   brute_force detection rate: 0.1519
#   ddos detection rate: 0.5696
#   dns_spoofing detection rate: 0.3067
#   dos detection rate: 0.6008
#   xss detection rate: 0.2815
# bottleneck=32, percentile=95: Precision=0.1781, Recall=0.2963, F1=0.2225
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  352  1624]
#  [  836 36376]]
#   brute_force detection rate: 0.1013
#   ddos detection rate: 0.4093
#   dns_spoofing detection rate: 0.2479
#   dos detection rate: 0.4790
#   xss detection rate: 0.2437
# bottleneck=32, percentile=97: Precision=0.1935, Recall=0.1961, F1=0.1948
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  233   971]
#  [  955 37029]]
#   brute_force detection rate: 0.0338
#   ddos detection rate: 0.2236
#   dns_spoofing detection rate: 0.1597
#   dos detection rate: 0.3613
#   xss detection rate: 0.2017
# bottleneck=32, percentile=99: Precision=0.2876, Recall=0.0934, F1=0.1410
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  111   275]
#  [ 1077 37725]]
#   brute_force detection rate: 0.0084
#   ddos detection rate: 0.0506
#   dns_spoofing detection rate: 0.0798
#   dos detection rate: 0.2311
#   xss detection rate: 0.0966
#     bottleneck_size  threshold_percentile  threshold  precision        f1  \
# 0                 2                    80   0.338296   0.090226  0.157068
# 1                32                    80   0.029222   0.090450  0.156766
# 2                 4                    80   0.198295   0.086012  0.149694
# 3                 2                    85   0.387627   0.114768  0.191199
# 4                16                    80   0.064999   0.084661  0.147049
# 5                 2                    90   0.452261   0.165519  0.254061
# 6                 2                    92   0.494047   0.197436  0.285980
# 7                32                    85   0.034536   0.104577  0.173764
# 8                 8                    80   0.122398   0.074482  0.129507
# 9                 4                    85   0.225335   0.097529  0.162949
# 10               16                    85   0.075138   0.093585  0.155697
# 11                2                    95   0.599069   0.267442  0.334176
# 12               32                    90   0.042851   0.126106  0.193975
# 13                8                    85   0.140231   0.079844  0.132919
# 14               32                    92   0.048356   0.142902  0.208018
# 15                4                    90   0.265551   0.113991  0.175513
# 16               16                    90   0.090429   0.109331  0.167936
# 17                2                    97   0.738701   0.337268  0.336984
# 18                4                    92   0.288743   0.123747  0.180365
# 19               16                    92   0.098918   0.120554  0.175487
# 20               32                    95   0.060866   0.178138  0.222503
# 21                8                    90   0.164355   0.087153  0.134337
# 22                8                    92   0.179700   0.095193  0.138641
# 23                4                    95   0.341857   0.139605  0.174408
# 24               16                    95   0.119297   0.137861  0.172097
# 25                8                    95   0.214896   0.121273  0.151563
# 26               32                    97   0.077525   0.193522  0.194816
# 27               16                    97   0.143957   0.158304  0.156143
# 28                4                    97   0.404893   0.152340  0.151502
# 29                8                    97   0.253392   0.140586  0.140999
# 30                2                    99   1.148348   0.306701  0.151015
# 31               32                    99   0.121973   0.287565  0.141042
# 32                4                    99   0.560485   0.190601  0.092934
# 33               16                    99   0.206013   0.187668  0.089686
# 34                8                    99   0.353854   0.136612  0.064350
#
#       recall       fpr       fnr
# 0   0.606061  0.191053  0.393939
# 1   0.587542  0.184711  0.412458
# 2   0.576599  0.191553  0.423401
# 3   0.572391  0.138026  0.427609
# 4   0.558923  0.188921  0.441077
# 5   0.546296  0.086105  0.453704
# 6   0.518519  0.065895  0.481481
# 7   0.513468  0.137447  0.486532
# 8   0.495791  0.192605  0.504209
# 9   0.494949  0.143184  0.505051
# 10  0.462963  0.140184  0.537037
# 11  0.445286  0.038132  0.554714
# 12  0.420034  0.091000  0.579966
# 13  0.396465  0.142842  0.603535
# 14  0.382155  0.071658  0.617845
# 15  0.381313  0.092658  0.618687
# 16  0.361953  0.092184  0.638047
# 17  0.336700  0.020684  0.663300
# 18  0.332492  0.073605  0.667508
# 19  0.322391  0.073526  0.677609
# 20  0.296296  0.042737  0.703704
# 21  0.292929  0.095921  0.707071
# 22  0.255051  0.075789  0.744949
# 23  0.232323  0.044763  0.767677
# 24  0.228956  0.044763  0.771044
# 25  0.202020  0.045763  0.797980
# 26  0.196128  0.025553  0.803872
# 27  0.154040  0.025605  0.845960
# 28  0.150673  0.026211  0.849327
# 29  0.141414  0.027026  0.858586
# 30  0.100168  0.007079  0.899832
# 31  0.093434  0.007237  0.906566
# 32  0.061448  0.008158  0.938552
# 33  0.058923  0.007974  0.941077
# 34  0.042088  0.008316  0.957912
# Final autoencoder test: bottleneck=2, percentile=85, Precision=0.1162, Recall=0.5867, F1=0.1940, FPR=0.1395, FNR=0.4133, ROC-AUC=0.8132, PR-AUC=0.1943
# [[  697  5300]
#  [  491 32700]]
#   brute_force detection rate: 0.2059
#   ddos detection rate: 0.9790
#   dns_spoofing detection rate: 0.3376
#   dos detection rate: 1.0000
#   xss detection rate: 0.4093

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 9))
axes = axes.ravel()

for axis, metric, title in zip(
    axes[:5],
    ["precision", "recall", "f1", "fpr", "fnr"],
    ["Precision", "Recall", "F1 Score", "False Positive Rate", "False Negative Rate"],
):
    for percentile in threshold_percentiles:
        subset = ae_results_df[
            ae_results_df["threshold_percentile"] == percentile
        ].sort_values("bottleneck_size")
        axis.plot(
            subset["bottleneck_size"],
            subset[metric],
            marker="o",
            label=f"Percentile {percentile}",
        )
    axis.set(title=title, xlabel="Bottleneck size", ylabel="Score")
    axis.set_xticks(bottleneck_sizes)
    axis.grid(alpha=0.3)
    axis.legend()

axes[5].axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Final Phase 2 Test Curves

# %%
from sklearn.metrics import roc_curve, precision_recall_curve

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

for name, scores in [
    ("K-means", kmeans_test_scores),
    ("Autoencoder", ae_test_scores),
]:
    fpr_curve, tpr_curve, _ = roc_curve(ae_test_truth, scores)
    curve_precision, curve_recall, _ = precision_recall_curve(ae_test_truth, scores)
    axes[0].plot(fpr_curve, tpr_curve, label=name)
    axes[1].plot(curve_recall, curve_precision, label=name)

axes[0].plot([0, 1], [0, 1], "--", color="gray")
axes[0].set(title="Test ROC Curve", xlabel="False Positive Rate", ylabel="True Positive Rate")
axes[1].set(title="Test Precision-Recall Curve", xlabel="Recall", ylabel="Precision")
for axis in axes:
    axis.grid(alpha=0.3)
    axis.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Brute-force/session feature engineering experiment
#
# The cells below build an alternate numeric feature table for brute-force-sensitive unsupervised learning. Raw string identifiers such as IP addresses, MAC addresses, and device names are used only as grouping keys, then removed before scaling/modeling so they do not explode dimensionality or distort K-means distances.

# %%
import ipaddress
import numpy as np
import pandas as pd

# Step 1: Reload the ForData feature table and packet identity table.
# The identity table gives us source/destination/session fields that are useful grouping keys.
brute_base_df = pd.read_csv("packet-data/for_data.csv")
packet_identity_df = pd.read_csv("packet-data/packet_data_ids.csv")

# Step 2: Join packet identities by packet id.
# We keep labels for evaluation, but labels are not used to construct any feature values.
brute_feature_df = brute_base_df.merge(packet_identity_df, on="id", how="left")

print("Base feature shape:", brute_base_df.shape)
print("Identity table shape:", packet_identity_df.shape)
print("Joined feature shape:", brute_feature_df.shape)
brute_feature_df.head()
# Out:
# Base feature shape: (195940, 111)
# Identity table shape: (206000, 11)
# Joined feature shape: (195940, 121)
#    average_p  channel_10_count  channel_10_mean  channel_10_var  \
# 0  -0.860521         -1.583750        -0.842800        0.770734
# 1  -0.624307         -0.267315        -0.762879       -0.361961
# 2  -0.988567         -0.810731        -0.436235        0.300095
# 3  -0.432299         -0.195494        -0.885616       -1.022598
# 4  -0.967851          0.188032        -0.835100       -1.149712
#
#    channel_1_count  channel_1_mean  channel_1_var  channel_30_count  \
# 0        -1.315677       -0.811806      -1.432881         -1.829250
# 1        -0.342127       -0.750525      -0.065298          0.137678
# 2        -0.722586       -0.442007       0.569104         -0.593623
# 3        -1.053230       -0.784335      -0.055243         -0.039735
# 4        -0.418365       -0.797316      -0.482272          0.042701
#
#    channel_30_mean  channel_30_var  ...  stream              src_mac  \
# 0        -0.842158        0.785753  ...    4526    e8:1b:69:f8:d6:e6
# 1        -0.774956       -0.462472  ...    3159    3c:18:a0:41:c3:a0
# 2        -0.439821        0.272999  ...      59    Amazon Echo Dot 2
# 3        -0.866857       -0.444237  ...      -1    5c:26:0a:28:80:77
# 4        -0.832494       -1.139550  ...      -1  AMCREST WiFi Camera
#
#               dst_mac           src_ip          dst_ip  src_port  dst_port  \
# 0   3c:18:a0:41:c3:a0  192.168.137.233   192.168.137.1     41274        53
# 1  Nest Indoor Camera   173.255.124.25   192.168.137.2       443     33776
# 2  Amazon Echo Studio   192.168.137.58  192.168.137.83     55443     43456
# 3   33:33:00:00:00:16              NaN             NaN         0         0
# 4   3c:18:a0:41:c3:a0   192.168.137.16   192.168.137.1         0         0
#
#             device_mac                                  eth_src_oui  \
# 0    e8:1b:69:f8:d6:e6                         Sercomm Corporation.
# 1   Nest Indoor Camera  Luxshare Precision Industry Company Limited
# 2    Amazon Echo Dot 2                     Amazon Technologies Inc.
# 3    5c:26:0a:28:80:77                                    Dell Inc.
# 4  AMCREST WiFi Camera                         Amcrest Technologies
#
#                                    eth_dst_oui
# 0  Luxshare Precision Industry Company Limited
# 1                                 Google, Inc.
# 2                     Amazon Technologies Inc.
# 3                               IPv6 Multicast
# 4  Luxshare Precision Industry Company Limited
#
# [5 rows x 121 columns]

# %%
# Step 3: Normalize grouping columns so missing values do not break groupby operations.
# These columns are still not model inputs; they only define behavioral groups.
brute_feature_df = brute_feature_df.sort_values("id").reset_index(drop=True)
brute_feature_df["packet_order"] = np.arange(len(brute_feature_df))

string_group_cols = [
    "stream", "src_mac", "dst_mac", "src_ip", "dst_ip", "device_mac",
    "eth_src_oui", "eth_dst_oui",
]
for col in string_group_cols:
    if col in brute_feature_df.columns:
        brute_feature_df[col] = brute_feature_df[col].fillna("missing").astype(str)

# Step 4: Clean port fields as numeric values.
# Missing or non-IP packets often have port 0; we keep that as a separate behavior signal.
for col in ["src_port", "dst_port"]:
    brute_feature_df[col] = pd.to_numeric(brute_feature_df[col], errors="coerce").fillna(0).astype(int)
# Out:
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/2877020922.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["packet_order"] = np.arange(len(brute_feature_df))

# %%
# Step 5: Add small, low-dimensional IP/port semantic flags.
# These avoid one-hot encoding raw IPs while still preserving useful network meaning.
def safe_ip_flag(value, attr):
    try:
        return int(getattr(ipaddress.ip_address(str(value)), attr))
    except ValueError:
        return 0

brute_feature_df["src_ip_is_private"] = brute_feature_df["src_ip"].apply(lambda x: safe_ip_flag(x, "is_private"))
brute_feature_df["dst_ip_is_private"] = brute_feature_df["dst_ip"].apply(lambda x: safe_ip_flag(x, "is_private"))
brute_feature_df["dst_ip_is_multicast"] = brute_feature_df["dst_ip"].apply(lambda x: safe_ip_flag(x, "is_multicast"))
brute_feature_df["dst_ip_is_loopback"] = brute_feature_df["dst_ip"].apply(lambda x: safe_ip_flag(x, "is_loopback"))

# Step 6: Add compact port-class indicators that are useful for brute-force behavior.
login_or_web_ports = {21, 22, 23, 80, 443, 8080, 8443}
brute_feature_df["dst_port_is_login_or_web"] = brute_feature_df["dst_port"].isin(login_or_web_ports).astype(int)
brute_feature_df["dst_port_is_well_known"] = ((brute_feature_df["dst_port"] > 0) & (brute_feature_df["dst_port"] < 1024)).astype(int)
brute_feature_df["src_port_is_ephemeral"] = (brute_feature_df["src_port"] >= 49152).astype(int)
brute_feature_df["has_valid_ports"] = ((brute_feature_df["src_port"] > 0) & (brute_feature_df["dst_port"] > 0)).astype(int)
# Out:
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/452007203.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_ip_is_private"] = brute_feature_df["src_ip"].apply(lambda x: safe_ip_flag(x, "is_private"))
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/452007203.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["dst_ip_is_private"] = brute_feature_df["dst_ip"].apply(lambda x: safe_ip_flag(x, "is_private"))
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/452007203.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["dst_ip_is_multicast"] = brute_feature_df["dst_ip"].apply(lambda x: safe_ip_flag(x, "is_multicast"))
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/452007203.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["dst_ip_is_loopback"] = brute_feature_df["dst_ip"].apply(lambda x: safe_ip_flag(x, "is_loopback"))
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/452007203.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["dst_port_is_login_or_web"] = brute_feature_df["dst_port"].isin(login_or_web_ports).astype(int)
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/452007203.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["dst_port_is_well_known"] = ((brute_feature_df["dst_port"] > 0) & (brute_feature_df["dst_port"] < 1024)).astype(int)
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/452007203.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_port_is_ephemeral"] = (brute_feature_df["src_port"] >= 49152).astype(int)
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/452007203.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["has_valid_ports"] = ((brute_feature_df["src_port"] > 0) & (brute_feature_df["dst_port"] > 0)).astype(int)

# %%
# Step 7: Add backward-looking repetition counts.
# These are better for anomaly detection than global one-hot identity features because they measure behavior.
# cumcount() uses only packets seen earlier in id order plus the current packet.
brute_feature_df["src_packets_seen_so_far"] = brute_feature_df.groupby("src_ip").cumcount() + 1
brute_feature_df["src_dst_packets_seen_so_far"] = brute_feature_df.groupby(["src_ip", "dst_ip"]).cumcount() + 1
brute_feature_df["src_dst_port_packets_seen_so_far"] = brute_feature_df.groupby(["src_ip", "dst_ip", "dst_port"]).cumcount() + 1
brute_feature_df["stream_packets_seen_so_far"] = brute_feature_df.groupby("stream").cumcount() + 1

# Step 8: Add cumulative unique-count features for source behavior.
# These capture whether a source is spreading attempts across many destinations or ports.
brute_feature_df["src_unique_dst_ips_seen_so_far"] = (
    (~brute_feature_df.duplicated(["src_ip", "dst_ip"]))
    .groupby(brute_feature_df["src_ip"])
    .cumsum()
    .astype(int)
)
brute_feature_df["src_unique_dst_ports_seen_so_far"] = (
    (~brute_feature_df.duplicated(["src_ip", "dst_port"]))
    .groupby(brute_feature_df["src_ip"])
    .cumsum()
    .astype(int)
)
brute_feature_df["stream_unique_dst_ips_seen_so_far"] = (
    (~brute_feature_df.duplicated(["stream", "dst_ip"]))
    .groupby(brute_feature_df["stream"])
    .cumsum()
    .astype(int)
)
brute_feature_df["stream_unique_dst_ports_seen_so_far"] = (
    (~brute_feature_df.duplicated(["stream", "dst_port"]))
    .groupby(brute_feature_df["stream"])
    .cumsum()
    .astype(int)
)
# Out:
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/624102379.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_packets_seen_so_far"] = brute_feature_df.groupby("src_ip").cumcount() + 1
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/624102379.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_dst_packets_seen_so_far"] = brute_feature_df.groupby(["src_ip", "dst_ip"]).cumcount() + 1
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/624102379.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_dst_port_packets_seen_so_far"] = brute_feature_df.groupby(["src_ip", "dst_ip", "dst_port"]).cumcount() + 1
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/624102379.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["stream_packets_seen_so_far"] = brute_feature_df.groupby("stream").cumcount() + 1
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/624102379.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_unique_dst_ips_seen_so_far"] = (
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/624102379.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_unique_dst_ports_seen_so_far"] = (
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/624102379.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["stream_unique_dst_ips_seen_so_far"] = (
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/624102379.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["stream_unique_dst_ports_seen_so_far"] = (

# %%
# Step 9: Add brute-force-oriented ratios.
# High repeated attempts to the same destination/port, especially on login/web ports, are suspicious.
eps = 1e-9
brute_feature_df["src_dst_port_repeat_ratio"] = (
    brute_feature_df["src_dst_port_packets_seen_so_far"] /
    (brute_feature_df["src_packets_seen_so_far"] + eps)
)
brute_feature_df["src_dst_repeat_ratio"] = (
    brute_feature_df["src_dst_packets_seen_so_far"] /
    (brute_feature_df["src_packets_seen_so_far"] + eps)
)
brute_feature_df["src_dst_port_login_attempt_score"] = (
    brute_feature_df["src_dst_port_packets_seen_so_far"] *
    brute_feature_df["dst_port_is_login_or_web"]
)
brute_feature_df["src_port_diversity_ratio"] = (
    brute_feature_df["src_unique_dst_ports_seen_so_far"] /
    (brute_feature_df["src_packets_seen_so_far"] + eps)
)
brute_feature_df["src_dst_diversity_ratio"] = (
    brute_feature_df["src_unique_dst_ips_seen_so_far"] /
    (brute_feature_df["src_packets_seen_so_far"] + eps)
)
# Out:
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/780544465.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_dst_port_repeat_ratio"] = (
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/780544465.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_dst_repeat_ratio"] = (
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/780544465.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_dst_port_login_attempt_score"] = (
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/780544465.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_port_diversity_ratio"] = (
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/780544465.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   brute_feature_df["src_dst_diversity_ratio"] = (

# %%
# Step 10: Add packet-window activity counts without using raw string values as model inputs.
# These approximate short-term behavior using packet order because this table does not include an absolute timestamp.
# If a real timestamp is available in earlier preprocessing, replace this with time-based rolling windows.
def add_packet_window_count(frame, group_cols, output_col, window_packets):
    counts = []
    group_values = frame[group_cols].astype(str).agg("|".join, axis=1)
    for i, key in enumerate(group_values):
        start = max(0, i - window_packets + 1)
        counts.append((group_values.iloc[start:i + 1] == key).sum())
    frame[output_col] = counts

add_packet_window_count(brute_feature_df, ["src_ip"], "src_count_last_100_packets", 100)
add_packet_window_count(brute_feature_df, ["src_ip", "dst_ip"], "src_dst_count_last_100_packets", 100)
add_packet_window_count(brute_feature_df, ["src_ip", "dst_ip", "dst_port"], "src_dst_port_count_last_100_packets", 100)
add_packet_window_count(brute_feature_df, ["src_ip", "dst_ip", "dst_port"], "src_dst_port_count_last_500_packets", 500)
# Out:
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/3037339688.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[output_col] = counts
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/3037339688.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[output_col] = counts
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/3037339688.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[output_col] = counts
# /var/folders/0m/_hz3ft2s6md80rlz1dzk50sw0000gn/T/ipykernel_40645/3037339688.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame[output_col] = counts

# %%
# Step 11: Build a numeric-only modeling table.
# Raw identifiers are dropped so K-means/autoencoder distances are based on behavior, not categorical identity.
raw_identifier_cols = [
    "src_mac", "dst_mac", "src_ip", "dst_ip", "device_mac",
    "eth_src_oui", "eth_dst_oui", "stream",
]
target_cols = ["label"]

brute_model_df = brute_feature_df.drop(columns=raw_identifier_cols, errors="ignore")

# Keep only numeric features plus label/id for splitting and evaluation.
numeric_feature_cols = brute_model_df.drop(columns=target_cols, errors="ignore").select_dtypes(include=[np.number]).columns.tolist()
brute_model_df = brute_model_df[numeric_feature_cols + target_cols]

# Replace any remaining infinite values from ratios and fill numeric missing values.
numeric_cols = brute_model_df.drop(columns=target_cols, errors="ignore").columns
brute_model_df[numeric_cols] = brute_model_df[numeric_cols].replace([np.inf, -np.inf], np.nan).fillna(0)

print("Numeric-only brute-force feature table shape:", brute_model_df.shape)
print("Added numeric features:")
added_cols = sorted(set(brute_model_df.columns) - set(brute_base_df.columns))
print(added_cols)
brute_model_df.head()
# Out:
# Numeric-only brute-force feature table shape: (195940, 139)
# Added numeric features:
# ['dst_ip_is_loopback', 'dst_ip_is_multicast', 'dst_ip_is_private', 'dst_port', 'dst_port_is_login_or_web', 'dst_port_is_well_known', 'has_valid_ports', 'packet_order', 'src_count_last_100_packets', 'src_dst_count_last_100_packets', 'src_dst_diversity_ratio', 'src_dst_packets_seen_so_far', 'src_dst_port_count_last_100_packets', 'src_dst_port_count_last_500_packets', 'src_dst_port_login_attempt_score', 'src_dst_port_packets_seen_so_far', 'src_dst_port_repeat_ratio', 'src_dst_repeat_ratio', 'src_ip_is_private', 'src_packets_seen_so_far', 'src_port', 'src_port_diversity_ratio', 'src_port_is_ephemeral', 'src_unique_dst_ips_seen_so_far', 'src_unique_dst_ports_seen_so_far', 'stream_packets_seen_so_far', 'stream_unique_dst_ips_seen_so_far', 'stream_unique_dst_ports_seen_so_far']
#    average_p  channel_10_count  channel_10_mean  channel_10_var  \
# 0  -0.860521         -1.583750        -0.842800        0.770734
# 1  -0.624307         -0.267315        -0.762879       -0.361961
# 2  -0.988567         -0.810731        -0.436235        0.300095
# 3  -0.432299         -0.195494        -0.885616       -1.022598
# 4  -0.967851          0.188032        -0.835100       -1.149712
#
#    channel_1_count  channel_1_mean  channel_1_var  channel_30_count  \
# 0        -1.315677       -0.811806      -1.432881         -1.829250
# 1        -0.342127       -0.750525      -0.065298          0.137678
# 2        -0.722586       -0.442007       0.569104         -0.593623
# 3        -1.053230       -0.784335      -0.055243         -0.039735
# 4        -0.418365       -0.797316      -0.482272          0.042701
#
#    channel_30_mean  channel_30_var  ...  src_dst_port_repeat_ratio  \
# 0        -0.842158        0.785753  ...                        1.0
# 1        -0.774956       -0.462472  ...                        1.0
# 2        -0.439821        0.272999  ...                        1.0
# 3        -0.866857       -0.444237  ...                        1.0
# 4        -0.832494       -1.139550  ...                        1.0
#
#    src_dst_repeat_ratio  src_dst_port_login_attempt_score  \
# 0                   1.0                                 0
# 1                   1.0                                 0
# 2                   1.0                                 0
# 3                   1.0                                 0
# 4                   1.0                                 0
#
#    src_port_diversity_ratio  src_dst_diversity_ratio  \
# 0                       1.0                      1.0
# 1                       1.0                      1.0
# 2                       1.0                      1.0
# 3                       1.0                      1.0
# 4                       1.0                      1.0
#
#    src_count_last_100_packets  src_dst_count_last_100_packets  \
# 0                           1                               1
# 1                           1                               1
# 2                           1                               1
# 3                           1                               1
# 4                           1                               1
#
#    src_dst_port_count_last_100_packets  src_dst_port_count_last_500_packets  \
# 0                                    1                                    1
# 1                                    1                                    1
# 2                                    1                                    1
# 3                                    1                                    1
# 4                                    1                                    1
#
#     label
# 0  benign
# 1  benign
# 2  benign
# 3  benign
# 4  benign
#
# [5 rows x 139 columns]

# %%
# Step 12: Create a train/validation/test split for this engineered feature set.
# This mirrors the earlier notebook split logic so results are comparable to the current ForData baseline.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_brute = brute_model_df.drop(columns=["label"], errors="ignore").to_numpy()
y_brute = brute_model_df["label"].to_numpy()

brute_row_indices = np.arange(X_brute.shape[0])
X_brute_train, X_brute_remaining, y_brute_train, y_brute_remaining, index_brute_train, index_brute_remaining = train_test_split(
    X_brute,
    y_brute,
    brute_row_indices,
    test_size=0.4,
    stratify=y_brute,
    random_state=Seed,
)
X_brute_validation, X_brute_test, y_brute_validation, y_brute_test, index_brute_validation, index_brute_test = train_test_split(
    X_brute_remaining,
    y_brute_remaining,
    index_brute_remaining,
    test_size=0.5,
    stratify=y_brute_remaining,
    random_state=Seed,
)

# Step 13: Fit scaling only on the training partition to avoid validation/test leakage.
brute_scaler = StandardScaler()
X_brute_train_scaled = brute_scaler.fit_transform(X_brute_train)
X_brute_validation_scaled = brute_scaler.transform(X_brute_validation)
X_brute_test_scaled = brute_scaler.transform(X_brute_test)

print("Engineered data matrix shape:", X_brute.shape)
print("Train/validation/test sizes:", X_brute_train.shape[0], X_brute_validation.shape[0], X_brute_test.shape[0])
print("Use X_brute_train_scaled, X_brute_validation_scaled, and X_brute_test_scaled to rerun K-means/autoencoder.")
# Out:
# Engineered data matrix shape: (195940, 138)
# Train/validation/test sizes: 117564 39188 39188
# Use X_brute_train_scaled, X_brute_validation_scaled, and X_brute_test_scaled to rerun K-means/autoencoder.

# %% [markdown]
# # Rerun K-means and autoencoder on engineered brute-force/session features
#
# These cells reuse the numeric-only feature matrix created above: `X_brute_train_scaled`, `X_brute_validation_scaled`, and `X_brute_test_scaled`. They keep results in new variables prefixed with `brute_` so the original ForData baseline remains available for comparison.

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    roc_auc_score,
    average_precision_score,
)

# Step 1: Define a shared metric reporter for binary anomaly detection.
# The model predicts only benign vs attack; per-type detection rates are computed using the original labels.
def summarize_attack_detection(y_true_labels, predicted_attack, anomaly_scores=None, prefix=""):
    true_attack = y_true_labels != "benign"
    precision = precision_score(true_attack, predicted_attack, zero_division=0)
    recall = recall_score(true_attack, predicted_attack, zero_division=0)
    f1 = f1_score(true_attack, predicted_attack, zero_division=0)
    tn, fp, fn, tp = confusion_matrix(true_attack, predicted_attack, labels=[False, True]).ravel()
    fpr = fp / (fp + tn) if (fp + tn) else 0.0
    fnr = fn / (fn + tp) if (fn + tp) else 0.0

    metrics = {
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "fpr": fpr,
        "fnr": fnr,
    }

    if anomaly_scores is not None:
        metrics["roc_auc"] = roc_auc_score(true_attack, anomaly_scores)
        metrics["pr_auc"] = average_precision_score(true_attack, anomaly_scores)

    print(
        f"{prefix}Precision={precision:.4f}, Recall={recall:.4f}, "
        f"F1={f1:.4f}, FPR={fpr:.4f}, FNR={fnr:.4f}"
    )
    if anomaly_scores is not None:
        print(f"{prefix}ROC-AUC={metrics['roc_auc']:.4f}, PR-AUC={metrics['pr_auc']:.4f}")

    print(f"{prefix}Confusion matrix [[TP, FP], [FN, TN]]:")
    print(np.array([[tp, fp], [fn, tn]]))

    for attack in sorted(np.unique(y_true_labels[y_true_labels != "benign"])):
        attack_mask = y_true_labels == attack
        detection_rate = predicted_attack[attack_mask].mean()
        metrics[f"{attack}_detection_rate"] = detection_rate
        print(f"{prefix}{attack} detection rate: {detection_rate:.4f}")

    return metrics

# %%
# Step 2: Rerun K-means on the engineered brute-force/session feature set.
# Labels are used only for validation/testing, not for fitting clusters.
brute_k_values = [2, 4, 6, 8, 10, 15, 20]
brute_threshold_percentiles = [80, 85, 90, 92, 95, 97, 99]

brute_kmeans_models = {}
brute_kmeans_thresholds = {}
brute_kmeans_results = []

brute_validation_truth = y_brute_validation != "benign"

for k in brute_k_values:
    # Step 2a: Fit K-means using only the engineered training features.
    model = KMeans(
        n_clusters=k,
        init="k-means++",
        n_init=5,
        random_state=Seed,
    )
    model.fit(X_brute_train_scaled)
    brute_kmeans_models[k] = model

    # Step 2b: Convert nearest-centroid distance into an anomaly score.
    train_distances = model.transform(X_brute_train_scaled).min(axis=1)
    validation_distances = model.transform(X_brute_validation_scaled).min(axis=1)

    for percentile in brute_threshold_percentiles:
        # Step 2c: Use a percentile of training distances as the anomaly threshold.
        threshold = np.percentile(train_distances, percentile)
        predicted_attack = validation_distances > threshold

        precision = precision_score(brute_validation_truth, predicted_attack, zero_division=0)
        recall = recall_score(brute_validation_truth, predicted_attack, zero_division=0)
        f1 = f1_score(brute_validation_truth, predicted_attack, zero_division=0)
        tn, fp, fn, tp = confusion_matrix(
            brute_validation_truth, predicted_attack, labels=[False, True]
        ).ravel()
        fpr = fp / (fp + tn) if (fp + tn) else 0.0
        fnr = fn / (fn + tp) if (fn + tp) else 0.0

        brute_kmeans_thresholds[(k, percentile)] = threshold
        brute_kmeans_results.append({
            "k": k,
            "threshold_percentile": percentile,
            "threshold": threshold,
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "fpr": fpr,
            "fnr": fnr,
        })

        print(
            f"brute K-means k={k}, percentile={percentile}: "
            f"Precision={precision:.4f}, Recall={recall:.4f}, F1={f1:.4f}, FPR={fpr:.4f}"
        )
        for attack in sorted(np.unique(y_brute_validation[y_brute_validation != "benign"])):
            attack_mask = y_brute_validation == attack
            print(f"  {attack} detection rate: {predicted_attack[attack_mask].mean():.4f}")

brute_kmeans_results_df = pd.DataFrame(brute_kmeans_results)
display(brute_kmeans_results_df.sort_values("fnr", ascending=True).reset_index(drop=True))

# Step 2d: Select the same kind of high-recall/low-FPR operating point used earlier.
eligible_brute_kmeans = brute_kmeans_results_df[
    (brute_kmeans_results_df["recall"] >= 0.90) &
    (brute_kmeans_results_df["fpr"] <= 0.15)
]
if eligible_brute_kmeans.empty:
    eligible_brute_kmeans = brute_kmeans_results_df[brute_kmeans_results_df["fpr"] <= 0.15]
if eligible_brute_kmeans.empty:
    eligible_brute_kmeans = brute_kmeans_results_df

best_brute_kmeans_config = eligible_brute_kmeans.sort_values(
    ["fnr", "fpr", "f1"], ascending=[True, True, False]
).iloc[0]

best_brute_k = int(best_brute_kmeans_config["k"])
best_brute_kmeans_percentile = int(best_brute_kmeans_config["threshold_percentile"])
best_brute_kmeans_model = brute_kmeans_models[best_brute_k]
best_brute_kmeans_threshold = brute_kmeans_thresholds[(best_brute_k, best_brute_kmeans_percentile)]

# Step 2e: Evaluate the selected K-means configuration on the held-out test set.
brute_kmeans_test_scores = best_brute_kmeans_model.transform(X_brute_test_scaled).min(axis=1)
brute_kmeans_test_predictions = brute_kmeans_test_scores > best_brute_kmeans_threshold

print(
    f"Final engineered-feature K-means test: k={best_brute_k}, "
    f"percentile={best_brute_kmeans_percentile}"
)
brute_kmeans_test_metrics = summarize_attack_detection(
    y_brute_test,
    brute_kmeans_test_predictions,
    brute_kmeans_test_scores,
    prefix="  ",
)
# Out:
# brute K-means k=2, percentile=80: Precision=0.1136, Recall=0.7668, F1=0.1979, FPR=0.1870
#   brute_force detection rate: 0.9283
#   ddos detection rate: 0.9705
#   dns_spoofing detection rate: 0.4118
#   dos detection rate: 0.8445
#   xss detection rate: 0.6807
# brute K-means k=2, percentile=85: Precision=0.1426, Recall=0.7205, F1=0.2381, FPR=0.1354
#   brute_force detection rate: 0.9156
#   ddos detection rate: 0.9241
#   dns_spoofing detection rate: 0.2983
#   dos detection rate: 0.7857
#   xss detection rate: 0.6807
# brute K-means k=2, percentile=90: Precision=0.1882, Recall=0.6313, F1=0.2900, FPR=0.0851
#   brute_force detection rate: 0.8692
#   ddos detection rate: 0.7384
#   dns_spoofing detection rate: 0.1765
#   dos detection rate: 0.7269
#   xss detection rate: 0.6471
# brute K-means k=2, percentile=92: Precision=0.2198, Recall=0.5875, F1=0.3200, FPR=0.0652
#   brute_force detection rate: 0.8270
#   ddos detection rate: 0.6498
#   dns_spoofing detection rate: 0.1471
#   dos detection rate: 0.7143
#   xss detection rate: 0.6008
# brute K-means k=2, percentile=95: Precision=0.3035, Recall=0.4848, F1=0.3733, FPR=0.0348
#   brute_force detection rate: 0.7426
#   ddos detection rate: 0.3840
#   dns_spoofing detection rate: 0.1176
#   dos detection rate: 0.6849
#   xss detection rate: 0.4958
# brute K-means k=2, percentile=97: Precision=0.3918, Recall=0.3687, F1=0.3799, FPR=0.0179
#   brute_force detection rate: 0.4726
#   ddos detection rate: 0.2700
#   dns_spoofing detection rate: 0.0630
#   dos detection rate: 0.6555
#   xss detection rate: 0.3824
# brute K-means k=2, percentile=99: Precision=0.5518, Recall=0.1658, F1=0.2550, FPR=0.0042
#   brute_force detection rate: 0.0759
#   ddos detection rate: 0.0717
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.5126
#   xss detection rate: 0.1597
# brute K-means k=4, percentile=80: Precision=0.1226, Recall=0.8215, F1=0.2134, FPR=0.1838
#   brute_force detection rate: 0.9367
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.4748
#   dos detection rate: 1.0000
#   xss detection rate: 0.6975
# brute K-means k=4, percentile=85: Precision=0.1602, Recall=0.8072, F1=0.2673, FPR=0.1323
#   brute_force detection rate: 0.9367
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.4286
#   dos detection rate: 0.9958
#   xss detection rate: 0.6807
# brute K-means k=4, percentile=90: Precision=0.2173, Recall=0.7382, F1=0.3358, FPR=0.0831
#   brute_force detection rate: 0.9198
#   ddos detection rate: 0.9156
#   dns_spoofing detection rate: 0.2899
#   dos detection rate: 0.8992
#   xss detection rate: 0.6681
# brute K-means k=4, percentile=92: Precision=0.2555, Recall=0.6961, F1=0.3738, FPR=0.0634
#   brute_force detection rate: 0.8987
#   ddos detection rate: 0.8565
#   dns_spoofing detection rate: 0.2353
#   dos detection rate: 0.8403
#   xss detection rate: 0.6513
# brute K-means k=4, percentile=95: Precision=0.3499, Recall=0.5623, F1=0.4314, FPR=0.0327
#   brute_force detection rate: 0.8059
#   ddos detection rate: 0.6329
#   dns_spoofing detection rate: 0.0924
#   dos detection rate: 0.7353
#   xss detection rate: 0.5462
# brute K-means k=4, percentile=97: Precision=0.4268, Recall=0.4099, F1=0.4182, FPR=0.0172
#   brute_force detection rate: 0.6118
#   ddos detection rate: 0.3165
#   dns_spoofing detection rate: 0.0168
#   dos detection rate: 0.6765
#   xss detection rate: 0.4286
# brute K-means k=4, percentile=99: Precision=0.5439, Recall=0.1616, F1=0.2492, FPR=0.0042
#   brute_force detection rate: 0.0717
#   ddos detection rate: 0.1055
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.4622
#   xss detection rate: 0.1597
# brute K-means k=6, percentile=80: Precision=0.1249, Recall=0.8367, F1=0.2174, FPR=0.1832
#   brute_force detection rate: 0.9325
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.5252
#   dos detection rate: 1.0000
#   xss detection rate: 0.7269
# brute K-means k=6, percentile=85: Precision=0.1599, Recall=0.8081, F1=0.2669, FPR=0.1328
#   brute_force detection rate: 0.9156
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.4412
#   dos detection rate: 1.0000
#   xss detection rate: 0.6849
# brute K-means k=6, percentile=90: Precision=0.2268, Recall=0.7710, F1=0.3506, FPR=0.0822
#   brute_force detection rate: 0.8776
#   ddos detection rate: 0.9916
#   dns_spoofing detection rate: 0.3277
#   dos detection rate: 0.9958
#   xss detection rate: 0.6639
# brute K-means k=6, percentile=92: Precision=0.2670, Recall=0.7189, F1=0.3894, FPR=0.0617
#   brute_force detection rate: 0.8397
#   ddos detection rate: 0.9367
#   dns_spoofing detection rate: 0.2269
#   dos detection rate: 0.9496
#   xss detection rate: 0.6429
# brute K-means k=6, percentile=95: Precision=0.3448, Recall=0.5758, F1=0.4313, FPR=0.0342
#   brute_force detection rate: 0.7511
#   ddos detection rate: 0.6751
#   dns_spoofing detection rate: 0.0840
#   dos detection rate: 0.8235
#   xss detection rate: 0.5462
# brute K-means k=6, percentile=97: Precision=0.4345, Recall=0.4217, F1=0.4280, FPR=0.0172
#   brute_force detection rate: 0.5654
#   ddos detection rate: 0.3797
#   dns_spoofing detection rate: 0.0168
#   dos detection rate: 0.7101
#   xss detection rate: 0.4370
# brute K-means k=6, percentile=99: Precision=0.6056, Recall=0.1810, F1=0.2787, FPR=0.0037
#   brute_force detection rate: 0.0802
#   ddos detection rate: 0.1224
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.5378
#   xss detection rate: 0.1555
# brute K-means k=8, percentile=80: Precision=0.1286, Recall=0.8510, F1=0.2235, FPR=0.1803
#   brute_force detection rate: 0.9283
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.5504
#   dos detection rate: 1.0000
#   xss detection rate: 0.7773
# brute K-means k=8, percentile=85: Precision=0.1629, Recall=0.8157, F1=0.2715, FPR=0.1311
#   brute_force detection rate: 0.9156
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.4580
#   dos detection rate: 1.0000
#   xss detection rate: 0.7059
# brute K-means k=8, percentile=90: Precision=0.2247, Recall=0.7593, F1=0.3468, FPR=0.0819
#   brute_force detection rate: 0.8565
#   ddos detection rate: 0.9873
#   dns_spoofing detection rate: 0.2773
#   dos detection rate: 1.0000
#   xss detection rate: 0.6765
# brute K-means k=8, percentile=92: Precision=0.2680, Recall=0.7281, F1=0.3918, FPR=0.0622
#   brute_force detection rate: 0.8186
#   ddos detection rate: 0.9705
#   dns_spoofing detection rate: 0.2059
#   dos detection rate: 0.9916
#   xss detection rate: 0.6555
# brute K-means k=8, percentile=95: Precision=0.3623, Recall=0.6136, F1=0.4556, FPR=0.0338
#   brute_force detection rate: 0.7511
#   ddos detection rate: 0.7975
#   dns_spoofing detection rate: 0.0756
#   dos detection rate: 0.8571
#   xss detection rate: 0.5882
# brute K-means k=8, percentile=97: Precision=0.4578, Recall=0.4470, F1=0.4523, FPR=0.0166
#   brute_force detection rate: 0.6118
#   ddos detection rate: 0.4177
#   dns_spoofing detection rate: 0.0126
#   dos detection rate: 0.7269
#   xss detection rate: 0.4664
# brute K-means k=8, percentile=99: Precision=0.5829, Recall=0.1835, F1=0.2791, FPR=0.0041
#   brute_force detection rate: 0.0675
#   ddos detection rate: 0.0886
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.5840
#   xss detection rate: 0.1681
# brute K-means k=10, percentile=80: Precision=0.1308, Recall=0.8620, F1=0.2272, FPR=0.1790
#   brute_force detection rate: 0.9494
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.5588
#   dos detection rate: 1.0000
#   xss detection rate: 0.8025
# brute K-means k=10, percentile=85: Precision=0.1672, Recall=0.8283, F1=0.2782, FPR=0.1290
#   brute_force detection rate: 0.9156
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.4832
#   dos detection rate: 1.0000
#   xss detection rate: 0.7437
# brute K-means k=10, percentile=90: Precision=0.2352, Recall=0.7803, F1=0.3615, FPR=0.0793
#   brute_force detection rate: 0.8776
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.3529
#   dos detection rate: 1.0000
#   xss detection rate: 0.6765
# brute K-means k=10, percentile=92: Precision=0.2832, Recall=0.7567, F1=0.4122, FPR=0.0599
#   brute_force detection rate: 0.8650
#   ddos detection rate: 0.9831
#   dns_spoofing detection rate: 0.2647
#   dos detection rate: 1.0000
#   xss detection rate: 0.6723
# brute K-means k=10, percentile=95: Precision=0.3984, Recall=0.6616, F1=0.4973, FPR=0.0312
#   brute_force detection rate: 0.7806
#   ddos detection rate: 0.8734
#   dns_spoofing detection rate: 0.1134
#   dos detection rate: 0.9160
#   xss detection rate: 0.6261
# brute K-means k=10, percentile=97: Precision=0.5109, Recall=0.4924, F1=0.5015, FPR=0.0147
#   brute_force detection rate: 0.6793
#   ddos detection rate: 0.5021
#   dns_spoofing detection rate: 0.0168
#   dos detection rate: 0.7689
#   xss detection rate: 0.4958
# brute K-means k=10, percentile=99: Precision=0.6812, Recall=0.2104, F1=0.3215, FPR=0.0031
#   brute_force detection rate: 0.0844
#   ddos detection rate: 0.1435
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.5966
#   xss detection rate: 0.2185
# brute K-means k=15, percentile=80: Precision=0.1314, Recall=0.8628, F1=0.2281, FPR=0.1783
#   brute_force detection rate: 0.9283
#   ddos detection rate: 0.9409
#   dns_spoofing detection rate: 0.6176
#   dos detection rate: 0.9748
#   xss detection rate: 0.8529
# brute K-means k=15, percentile=85: Precision=0.1626, Recall=0.8022, F1=0.2704, FPR=0.1291
#   brute_force detection rate: 0.9030
#   ddos detection rate: 0.8608
#   dns_spoofing detection rate: 0.5462
#   dos detection rate: 0.9370
#   xss detection rate: 0.7647
# brute K-means k=15, percentile=90: Precision=0.2176, Recall=0.7264, F1=0.3349, FPR=0.0817
#   brute_force detection rate: 0.8228
#   ddos detection rate: 0.7975
#   dns_spoofing detection rate: 0.4328
#   dos detection rate: 0.8908
#   xss detection rate: 0.6891
# brute K-means k=15, percentile=92: Precision=0.2524, Recall=0.6793, F1=0.3681, FPR=0.0629
#   brute_force detection rate: 0.7637
#   ddos detection rate: 0.7426
#   dns_spoofing detection rate: 0.3655
#   dos detection rate: 0.8529
#   xss detection rate: 0.6723
# brute K-means k=15, percentile=95: Precision=0.3325, Recall=0.5682, F1=0.4195, FPR=0.0357
#   brute_force detection rate: 0.6203
#   ddos detection rate: 0.6624
#   dns_spoofing detection rate: 0.2185
#   dos detection rate: 0.6807
#   xss detection rate: 0.6597
# brute K-means k=15, percentile=97: Precision=0.4437, Recall=0.4444, F1=0.4441, FPR=0.0174
#   brute_force detection rate: 0.5232
#   ddos detection rate: 0.5063
#   dns_spoofing detection rate: 0.0966
#   dos detection rate: 0.4832
#   xss detection rate: 0.6134
# brute K-means k=15, percentile=99: Precision=0.6047, Recall=0.1944, F1=0.2943, FPR=0.0040
#   brute_force detection rate: 0.2954
#   ddos detection rate: 0.0928
#   dns_spoofing detection rate: 0.0126
#   dos detection rate: 0.1261
#   xss detection rate: 0.4454
# brute K-means k=20, percentile=80: Precision=0.1325, Recall=0.8754, F1=0.2302, FPR=0.1792
#   brute_force detection rate: 0.9367
#   ddos detection rate: 0.9494
#   dns_spoofing detection rate: 0.6429
#   dos detection rate: 0.9748
#   xss detection rate: 0.8739
# brute K-means k=20, percentile=85: Precision=0.1677, Recall=0.8249, F1=0.2788, FPR=0.1280
#   brute_force detection rate: 0.9156
#   ddos detection rate: 0.9030
#   dns_spoofing detection rate: 0.5714
#   dos detection rate: 0.9538
#   xss detection rate: 0.7815
# brute K-means k=20, percentile=90: Precision=0.2215, Recall=0.7306, F1=0.3400, FPR=0.0803
#   brute_force detection rate: 0.8270
#   ddos detection rate: 0.7890
#   dns_spoofing detection rate: 0.4496
#   dos detection rate: 0.8866
#   xss detection rate: 0.7017
# brute K-means k=20, percentile=92: Precision=0.2564, Recall=0.6835, F1=0.3729, FPR=0.0620
#   brute_force detection rate: 0.7722
#   ddos detection rate: 0.7300
#   dns_spoofing detection rate: 0.3782
#   dos detection rate: 0.8613
#   xss detection rate: 0.6765
# brute K-means k=20, percentile=95: Precision=0.3284, Recall=0.5471, F1=0.4105, FPR=0.0350
#   brute_force detection rate: 0.6034
#   ddos detection rate: 0.5612
#   dns_spoofing detection rate: 0.2311
#   dos detection rate: 0.6765
#   xss detection rate: 0.6639
# brute K-means k=20, percentile=97: Precision=0.4195, Recall=0.4209, F1=0.4202, FPR=0.0182
#   brute_force detection rate: 0.5063
#   ddos detection rate: 0.3249
#   dns_spoofing detection rate: 0.1218
#   dos detection rate: 0.5042
#   xss detection rate: 0.6471
# brute K-means k=20, percentile=99: Precision=0.5827, Recall=0.1869, F1=0.2830, FPR=0.0042
#   brute_force detection rate: 0.2489
#   ddos detection rate: 0.0675
#   dns_spoofing detection rate: 0.0126
#   dos detection rate: 0.1303
#   xss detection rate: 0.4748
#      k  threshold_percentile  threshold  precision    recall        f1  \
# 0   20                    80   7.719144   0.132501  0.875421  0.230165
# 1   15                    80   8.034550   0.131410  0.862795  0.228082
# 2   10                    80   8.435362   0.130829  0.861953  0.227177
# 3    8                    80   8.562783   0.128610  0.851010  0.223450
# 4    6                    80   8.912153   0.124921  0.836700  0.217387
# 5   10                    85   8.906510   0.167176  0.828283  0.278202
# 6   20                    85   8.257941   0.167722  0.824916  0.278765
# 7    4                    80   9.845363   0.122613  0.821549  0.213380
# 8    8                    85   9.072029   0.162885  0.815657  0.271543
# 9    6                    85   9.478707   0.159867  0.808081  0.266926
# 10   4                    85  10.410806   0.160180  0.807239  0.267317
# 11  15                    85   8.526214   0.162628  0.802189  0.270431
# 12  10                    90   9.636423   0.235219  0.780303  0.361474
# 13   6                    90  10.378592   0.226845  0.771044  0.350555
# 14   2                    80  10.656643   0.113619  0.766835  0.197914
# 15   8                    90  10.000956   0.224714  0.759259  0.346790
# 16  10                    92  10.111510   0.283239  0.756734  0.412196
# 17   4                    90  11.174889   0.217348  0.738215  0.335822
# 18  20                    90   9.037467   0.221542  0.730640  0.339992
# 19   8                    92  10.577667   0.267968  0.728114  0.391757
# 20  15                    90   9.246153   0.217600  0.726431  0.334886
# 21   2                    85  11.216708   0.142619  0.720539  0.238108
# 22   6                    92  10.902410   0.267042  0.718855  0.389421
# 23   4                    92  11.585353   0.255483  0.696128  0.373785
# 24  20                    92   9.448580   0.256394  0.683502  0.372905
# 25  15                    92   9.629946   0.252424  0.679293  0.368073
# 26  10                    95  11.166353   0.398378  0.661616  0.497311
# 27   2                    90  12.042408   0.188206  0.631313  0.289967
# 28   8                    95  11.620755   0.362326  0.613636  0.455625
# 29   2                    92  12.438395   0.219843  0.587542  0.319963
# 30   6                    95  11.910264   0.344758  0.575758  0.431274
# 31  15                    95  10.415676   0.332512  0.568182  0.419515
# 32   4                    95  12.510790   0.349921  0.562290  0.431385
# 33  20                    95  10.262627   0.328449  0.547138  0.410483
# 34  10                    97  12.400261   0.510917  0.492424  0.501500
# 35   2                    95  13.295522   0.303477  0.484848  0.373299
# 36   8                    97  12.980492   0.457759  0.446970  0.452300
# 37  15                    97  11.184028   0.443697  0.444444  0.444071
# 38   6                    97  13.295484   0.434519  0.421717  0.428022
# 39  20                    97  11.019181   0.419463  0.420875  0.420168
# 40   4                    97  13.936954   0.426819  0.409933  0.418205
# 41   2                    97  14.495523   0.391771  0.368687  0.379879
# 42  10                    99  17.236560   0.681199  0.210438  0.321543
# 43  15                    99  12.794913   0.604712  0.194444  0.294268
# 44  20                    99  12.592382   0.582677  0.186869  0.282983
# 45   8                    99  18.051780   0.582888  0.183502  0.279129
# 46   6                    99  18.503306   0.605634  0.180976  0.278678
# 47   2                    99  19.496156   0.551821  0.165825  0.255016
# 48   4                    99  19.169961   0.543909  0.161616  0.249189
#
#          fpr       fnr
# 0   0.179184  0.124579
# 1   0.178289  0.137205
# 2   0.179026  0.138047
# 3   0.180263  0.148990
# 4   0.183237  0.163300
# 5   0.129000  0.171717
# 6   0.127974  0.175084
# 7   0.183789  0.178451
# 8   0.131053  0.184343
# 9   0.132763  0.191919
# 10  0.132316  0.192761
# 11  0.129132  0.197811
# 12  0.079316  0.219697
# 13  0.082158  0.228956
# 14  0.187026  0.233165
# 15  0.081895  0.240741
# 16  0.059868  0.243266
# 17  0.083105  0.261785
# 18  0.080263  0.269360
# 19  0.062184  0.271886
# 20  0.081658  0.273569
# 21  0.135421  0.279461
# 22  0.061684  0.281145
# 23  0.063421  0.303872
# 24  0.061974  0.316498
# 25  0.062895  0.320707
# 26  0.031237  0.338384
# 27  0.085132  0.368687
# 28  0.033763  0.386364
# 29  0.065184  0.412458
# 30  0.034211  0.424242
# 31  0.035658  0.431818
# 32  0.032658  0.437710
# 33  0.034974  0.452862
# 34  0.014737  0.507576
# 35  0.034789  0.515152
# 36  0.016553  0.553030
# 37  0.017421  0.555556
# 38  0.017158  0.578283
# 39  0.018211  0.579125
# 40  0.017211  0.590067
# 41  0.017895  0.631313
# 42  0.003079  0.789562
# 43  0.003974  0.805556
# 44  0.004184  0.813131
# 45  0.004105  0.816498
# 46  0.003684  0.819024
# 47  0.004211  0.834175
# 48  0.004237  0.838384
# Final engineered-feature K-means test: k=10, percentile=85
#   Precision=0.1635, Recall=0.8359, F1=0.2736, FPR=0.1337, FNR=0.1641
#   ROC-AUC=0.9305, PR-AUC=0.4089
#   Confusion matrix [[TP, FP], [FN, TN]]:
# [[  993  5079]
#  [  195 32921]]
#   brute_force detection rate: 0.9328
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.5105
#   dos detection rate: 1.0000
#   xss detection rate: 0.7342

# %%
import tensorflow as tf
import keras

# Step 3: Rerun the autoencoder on the engineered brute-force/session feature set.
# The autoencoder learns reconstruction of the engineered numeric behavior features.
keras.utils.set_random_seed(Seed)

brute_bottleneck_sizes = [2, 4, 8, 16, 32]
brute_ae_threshold_percentiles = [80, 85, 90, 92, 95, 97, 99]

X_brute_train_ae = X_brute_train_scaled.astype(np.float32)
X_brute_validation_ae = X_brute_validation_scaled.astype(np.float32)
X_brute_test_ae = X_brute_test_scaled.astype(np.float32)
brute_ae_validation_truth = y_brute_validation != "benign"

brute_autoencoder_models = {}
brute_ae_results = []
brute_ae_thresholds = {}

brute_input_dim = X_brute_train_ae.shape[1]

for bottleneck_size in brute_bottleneck_sizes:
    # Step 3a: Build a small symmetric autoencoder for the current bottleneck size.
    keras.backend.clear_session()
    keras.utils.set_random_seed(Seed)

    inputs = keras.Input(shape=(brute_input_dim,))
    encoded = keras.layers.Dense(64, activation="relu")(inputs)
    bottleneck = keras.layers.Dense(bottleneck_size, activation="relu", name="bottleneck")(encoded)
    decoded = keras.layers.Dense(64, activation="relu")(bottleneck)
    outputs = keras.layers.Dense(brute_input_dim)(decoded)

    autoencoder = keras.Model(inputs, outputs, name=f"brute_autoencoder_{bottleneck_size}")
    autoencoder.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="mse",
    )

    # Step 3b: Train reconstruction on the training partition only.
    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True,
    )
    history = autoencoder.fit(
        X_brute_train_ae,
        X_brute_train_ae,
        epochs=50,
        batch_size=512,
        validation_split=0.1,
        shuffle=True,
        callbacks=[early_stopping],
        verbose=0,
    )
    brute_autoencoder_models[bottleneck_size] = autoencoder
    print(f"Brute AE bottleneck {bottleneck_size}: trained for {len(history.history['loss'])} epochs")

    # Step 3c: Convert reconstruction error into an anomaly score.
    train_reconstruction = autoencoder.predict(X_brute_train_ae, verbose=0)
    train_errors = np.mean((X_brute_train_ae - train_reconstruction) ** 2, axis=1)
    validation_reconstruction = autoencoder.predict(X_brute_validation_ae, verbose=0)
    validation_errors = np.mean((X_brute_validation_ae - validation_reconstruction) ** 2, axis=1)

    for percentile in brute_ae_threshold_percentiles:
        # Step 3d: Use a percentile of training reconstruction errors as the anomaly threshold.
        threshold = np.percentile(train_errors, percentile)
        predicted_attack = validation_errors > threshold

        precision = precision_score(brute_ae_validation_truth, predicted_attack, zero_division=0)
        recall = recall_score(brute_ae_validation_truth, predicted_attack, zero_division=0)
        f1 = f1_score(brute_ae_validation_truth, predicted_attack, zero_division=0)
        tn, fp, fn, tp = confusion_matrix(
            brute_ae_validation_truth, predicted_attack, labels=[False, True]
        ).ravel()
        fpr = fp / (fp + tn) if (fp + tn) else 0.0
        fnr = fn / (fn + tp) if (fn + tp) else 0.0

        brute_ae_thresholds[(bottleneck_size, percentile)] = threshold
        brute_ae_results.append({
            "bottleneck_size": bottleneck_size,
            "threshold_percentile": percentile,
            "threshold": threshold,
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "fpr": fpr,
            "fnr": fnr,
        })

        print(
            f"brute AE bottleneck={bottleneck_size}, percentile={percentile}: "
            f"Precision={precision:.4f}, Recall={recall:.4f}, F1={f1:.4f}, FPR={fpr:.4f}"
        )
        for attack in sorted(np.unique(y_brute_validation[y_brute_validation != "benign"])):
            attack_mask = y_brute_validation == attack
            print(f"  {attack} detection rate: {predicted_attack[attack_mask].mean():.4f}")

brute_ae_results_df = pd.DataFrame(brute_ae_results)
display(brute_ae_results_df.sort_values("fnr", ascending=True).reset_index(drop=True))

# Step 3e: Select the same high-recall/low-FPR operating point used earlier.
eligible_brute_ae = brute_ae_results_df[
    (brute_ae_results_df["recall"] >= 0.90) &
    (brute_ae_results_df["fpr"] <= 0.15)
]
if eligible_brute_ae.empty:
    eligible_brute_ae = brute_ae_results_df[brute_ae_results_df["fpr"] <= 0.15]
if eligible_brute_ae.empty:
    eligible_brute_ae = brute_ae_results_df

best_brute_ae_config = eligible_brute_ae.sort_values(
    ["fnr", "fpr", "f1"], ascending=[True, True, False]
).iloc[0]

best_brute_ae_bottleneck = int(best_brute_ae_config["bottleneck_size"])
best_brute_ae_percentile = int(best_brute_ae_config["threshold_percentile"])
best_brute_ae_model = brute_autoencoder_models[best_brute_ae_bottleneck]
best_brute_ae_threshold = brute_ae_thresholds[(best_brute_ae_bottleneck, best_brute_ae_percentile)]

# Step 3f: Evaluate the selected autoencoder configuration on the held-out test set.
brute_ae_test_reconstruction = best_brute_ae_model.predict(X_brute_test_ae, verbose=0)
brute_ae_test_scores = np.mean((X_brute_test_ae - brute_ae_test_reconstruction) ** 2, axis=1)
brute_ae_test_predictions = brute_ae_test_scores > best_brute_ae_threshold

print(
    f"Final engineered-feature autoencoder test: bottleneck={best_brute_ae_bottleneck}, "
    f"percentile={best_brute_ae_percentile}"
)
brute_ae_test_metrics = summarize_attack_detection(
    y_brute_test,
    brute_ae_test_predictions,
    brute_ae_test_scores,
    prefix="  ",
)
# Out:
# Brute AE bottleneck 2: trained for 50 epochs
# brute AE bottleneck=2, percentile=80: Precision=0.1294, Recall=0.8620, F1=0.2250, FPR=0.1813
#   brute_force detection rate: 0.9451
#   ddos detection rate: 0.9789
#   dns_spoofing detection rate: 0.5252
#   dos detection rate: 0.9874
#   xss detection rate: 0.8739
# brute AE bottleneck=2, percentile=85: Precision=0.1640, Recall=0.8140, F1=0.2729, FPR=0.1298
#   brute_force detection rate: 0.9367
#   ddos detection rate: 0.9409
#   dns_spoofing detection rate: 0.4244
#   dos detection rate: 0.9496
#   xss detection rate: 0.8193
# brute AE bottleneck=2, percentile=90: Precision=0.2150, Recall=0.7138, F1=0.3304, FPR=0.0815
#   brute_force detection rate: 0.8945
#   ddos detection rate: 0.8228
#   dns_spoofing detection rate: 0.2941
#   dos detection rate: 0.8361
#   xss detection rate: 0.7227
# brute AE bottleneck=2, percentile=92: Precision=0.2394, Recall=0.6397, F1=0.3484, FPR=0.0636
#   brute_force detection rate: 0.8903
#   ddos detection rate: 0.7553
#   dns_spoofing detection rate: 0.2311
#   dos detection rate: 0.6597
#   xss detection rate: 0.6639
# brute AE bottleneck=2, percentile=95: Precision=0.2898, Recall=0.4874, F1=0.3635, FPR=0.0373
#   brute_force detection rate: 0.7932
#   ddos detection rate: 0.5612
#   dns_spoofing detection rate: 0.1134
#   dos detection rate: 0.3361
#   xss detection rate: 0.6345
# brute AE bottleneck=2, percentile=97: Precision=0.3662, Recall=0.3594, F1=0.3628, FPR=0.0194
#   brute_force detection rate: 0.6878
#   ddos detection rate: 0.2785
#   dns_spoofing detection rate: 0.0672
#   dos detection rate: 0.1681
#   xss detection rate: 0.5966
# brute AE bottleneck=2, percentile=99: Precision=0.5680, Recall=0.1793, F1=0.2726, FPR=0.0043
#   brute_force detection rate: 0.3755
#   ddos detection rate: 0.0759
#   dns_spoofing detection rate: 0.0126
#   dos detection rate: 0.0210
#   xss detection rate: 0.4118
# Brute AE bottleneck 4: trained for 50 epochs
# brute AE bottleneck=4, percentile=80: Precision=0.1339, Recall=0.8981, F1=0.2330, FPR=0.1817
#   brute_force detection rate: 0.8186
#   ddos detection rate: 0.9367
#   dns_spoofing detection rate: 0.8445
#   dos detection rate: 0.9748
#   xss detection rate: 0.9160
# brute AE bottleneck=4, percentile=85: Precision=0.1638, Recall=0.8241, F1=0.2732, FPR=0.1316
#   brute_force detection rate: 0.7215
#   ddos detection rate: 0.8861
#   dns_spoofing detection rate: 0.7731
#   dos detection rate: 0.8739
#   xss detection rate: 0.8655
# brute AE bottleneck=4, percentile=90: Precision=0.2066, Recall=0.6886, F1=0.3178, FPR=0.0827
#   brute_force detection rate: 0.5527
#   ddos detection rate: 0.7848
#   dns_spoofing detection rate: 0.6218
#   dos detection rate: 0.7059
#   xss detection rate: 0.7773
# brute AE bottleneck=4, percentile=92: Precision=0.2216, Recall=0.5892, F1=0.3221, FPR=0.0647
#   brute_force detection rate: 0.4726
#   ddos detection rate: 0.6793
#   dns_spoofing detection rate: 0.5378
#   dos detection rate: 0.5798
#   xss detection rate: 0.6765
# brute AE bottleneck=4, percentile=95: Precision=0.2453, Recall=0.4049, F1=0.3055, FPR=0.0389
#   brute_force detection rate: 0.2996
#   ddos detection rate: 0.4473
#   dns_spoofing detection rate: 0.2983
#   dos detection rate: 0.4118
#   xss detection rate: 0.5672
# brute AE bottleneck=4, percentile=97: Precision=0.2594, Recall=0.2660, F1=0.2627, FPR=0.0237
#   brute_force detection rate: 0.1941
#   ddos detection rate: 0.2574
#   dns_spoofing detection rate: 0.1597
#   dos detection rate: 0.2605
#   xss detection rate: 0.4580
# brute AE bottleneck=4, percentile=99: Precision=0.3854, Recall=0.1246, F1=0.1883, FPR=0.0062
#   brute_force detection rate: 0.0633
#   ddos detection rate: 0.0759
#   dns_spoofing detection rate: 0.0504
#   dos detection rate: 0.0798
#   xss detection rate: 0.3529
# Brute AE bottleneck 8: trained for 50 epochs
# brute AE bottleneck=8, percentile=80: Precision=0.1172, Recall=0.7753, F1=0.2036, FPR=0.1825
#   brute_force detection rate: 0.5190
#   ddos detection rate: 0.8397
#   dns_spoofing detection rate: 0.8739
#   dos detection rate: 0.8193
#   xss detection rate: 0.8235
# brute AE bottleneck=8, percentile=85: Precision=0.1336, Recall=0.6684, F1=0.2226, FPR=0.1356
#   brute_force detection rate: 0.4599
#   ddos detection rate: 0.7173
#   dns_spoofing detection rate: 0.7101
#   dos detection rate: 0.7731
#   xss detection rate: 0.6807
# brute AE bottleneck=8, percentile=90: Precision=0.1631, Recall=0.5412, F1=0.2507, FPR=0.0868
#   brute_force detection rate: 0.3629
#   ddos detection rate: 0.5485
#   dns_spoofing detection rate: 0.5546
#   dos detection rate: 0.6807
#   xss detection rate: 0.5588
# brute AE bottleneck=8, percentile=92: Precision=0.1803, Recall=0.4756, F1=0.2615, FPR=0.0676
#   brute_force detection rate: 0.3165
#   ddos detection rate: 0.4388
#   dns_spoofing detection rate: 0.4958
#   dos detection rate: 0.6134
#   xss detection rate: 0.5126
# brute AE bottleneck=8, percentile=95: Precision=0.2141, Recall=0.3418, F1=0.2633, FPR=0.0392
#   brute_force detection rate: 0.2321
#   ddos detection rate: 0.2574
#   dns_spoofing detection rate: 0.3151
#   dos detection rate: 0.4538
#   xss detection rate: 0.4496
# brute AE bottleneck=8, percentile=97: Precision=0.2562, Recall=0.2525, F1=0.2543, FPR=0.0229
#   brute_force detection rate: 0.1730
#   ddos detection rate: 0.1519
#   dns_spoofing detection rate: 0.2101
#   dos detection rate: 0.3403
#   xss detection rate: 0.3866
# brute AE bottleneck=8, percentile=99: Precision=0.3088, Recall=0.1061, F1=0.1579, FPR=0.0074
#   brute_force detection rate: 0.1139
#   ddos detection rate: 0.0253
#   dns_spoofing detection rate: 0.0714
#   dos detection rate: 0.1050
#   xss detection rate: 0.2143
# Brute AE bottleneck 16: trained for 50 epochs
# brute AE bottleneck=16, percentile=80: Precision=0.1253, Recall=0.8300, F1=0.2178, FPR=0.1811
#   brute_force detection rate: 0.6835
#   ddos detection rate: 0.8945
#   dns_spoofing detection rate: 0.7227
#   dos detection rate: 0.8782
#   xss detection rate: 0.9706
# brute AE bottleneck=16, percentile=85: Precision=0.1534, Recall=0.7584, F1=0.2552, FPR=0.1308
#   brute_force detection rate: 0.6034
#   ddos detection rate: 0.8312
#   dns_spoofing detection rate: 0.6597
#   dos detection rate: 0.7983
#   xss detection rate: 0.8992
# brute AE bottleneck=16, percentile=90: Precision=0.1916, Recall=0.6279, F1=0.2936, FPR=0.0828
#   brute_force detection rate: 0.4388
#   ddos detection rate: 0.6624
#   dns_spoofing detection rate: 0.5378
#   dos detection rate: 0.7143
#   xss detection rate: 0.7857
# brute AE bottleneck=16, percentile=92: Precision=0.2143, Recall=0.5623, F1=0.3103, FPR=0.0644
#   brute_force detection rate: 0.3713
#   ddos detection rate: 0.5823
#   dns_spoofing detection rate: 0.4664
#   dos detection rate: 0.6513
#   xss detection rate: 0.7395
# brute AE bottleneck=16, percentile=95: Precision=0.2458, Recall=0.4074, F1=0.3066, FPR=0.0391
#   brute_force detection rate: 0.2532
#   ddos detection rate: 0.3586
#   dns_spoofing detection rate: 0.3067
#   dos detection rate: 0.5336
#   xss detection rate: 0.5840
# brute AE bottleneck=16, percentile=97: Precision=0.2836, Recall=0.2862, F1=0.2849, FPR=0.0226
#   brute_force detection rate: 0.1899
#   ddos detection rate: 0.1772
#   dns_spoofing detection rate: 0.1933
#   dos detection rate: 0.4034
#   xss detection rate: 0.4664
# brute AE bottleneck=16, percentile=99: Precision=0.3489, Recall=0.1254, F1=0.1845, FPR=0.0073
#   brute_force detection rate: 0.0886
#   ddos detection rate: 0.0422
#   dns_spoofing detection rate: 0.0714
#   dos detection rate: 0.1975
#   xss detection rate: 0.2269
# Brute AE bottleneck 32: trained for 50 epochs
# brute AE bottleneck=32, percentile=80: Precision=0.1209, Recall=0.8005, F1=0.2101, FPR=0.1819
#   brute_force detection rate: 0.6540
#   ddos detection rate: 0.9578
#   dns_spoofing detection rate: 0.5966
#   dos detection rate: 0.9412
#   xss detection rate: 0.8529
# brute AE bottleneck=32, percentile=85: Precision=0.1463, Recall=0.7298, F1=0.2437, FPR=0.1331
#   brute_force detection rate: 0.5359
#   ddos detection rate: 0.9156
#   dns_spoofing detection rate: 0.4958
#   dos detection rate: 0.9160
#   xss detection rate: 0.7857
# brute AE bottleneck=32, percentile=90: Precision=0.1928, Recall=0.6355, F1=0.2958, FPR=0.0832
#   brute_force detection rate: 0.4304
#   ddos detection rate: 0.8523
#   dns_spoofing detection rate: 0.3824
#   dos detection rate: 0.8487
#   xss detection rate: 0.6639
# brute AE bottleneck=32, percentile=92: Precision=0.2177, Recall=0.5749, F1=0.3158, FPR=0.0646
#   brute_force detection rate: 0.3671
#   ddos detection rate: 0.7890
#   dns_spoofing detection rate: 0.3571
#   dos detection rate: 0.7731
#   xss detection rate: 0.5882
# brute AE bottleneck=32, percentile=95: Precision=0.2814, Recall=0.4562, F1=0.3481, FPR=0.0364
#   brute_force detection rate: 0.2616
#   ddos detection rate: 0.5992
#   dns_spoofing detection rate: 0.2857
#   dos detection rate: 0.6513
#   xss detection rate: 0.4832
# brute AE bottleneck=32, percentile=97: Precision=0.3427, Recall=0.3384, F1=0.3405, FPR=0.0203
#   brute_force detection rate: 0.1857
#   ddos detection rate: 0.3882
#   dns_spoofing detection rate: 0.1807
#   dos detection rate: 0.5336
#   xss detection rate: 0.4034
# brute AE bottleneck=32, percentile=99: Precision=0.4767, Recall=0.1549, F1=0.2338, FPR=0.0053
#   brute_force detection rate: 0.0886
#   ddos detection rate: 0.0802
#   dns_spoofing detection rate: 0.0546
#   dos detection rate: 0.3109
#   xss detection rate: 0.2395
#     bottleneck_size  threshold_percentile  threshold  precision    recall  \
# 0                 4                    80   0.232261   0.133877  0.898148
# 1                 2                    80   0.401901   0.129407  0.861953
# 2                16                    80   0.091079   0.125350  0.829966
# 3                 4                    85   0.267371   0.163767  0.824074
# 4                 2                    85   0.453723   0.163954  0.813973
# 5                32                    80   0.045648   0.120931  0.800505
# 6                 8                    80   0.157739   0.117220  0.775253
# 7                16                    85   0.103439   0.153414  0.758418
# 8                32                    85   0.052182   0.146304  0.729798
# 9                 2                    90   0.537508   0.214956  0.713805
# 10                4                    90   0.319847   0.206566  0.688552
# 11                8                    85   0.179515   0.133558  0.668350
# 12                2                    92   0.588056   0.239370  0.639731
# 13               32                    90   0.062210   0.192799  0.635522
# 14               16                    90   0.121541   0.191577  0.627946
# 15                4                    92   0.350126   0.221589  0.589226
# 16               32                    92   0.068141   0.217655  0.574916
# 17               16                    92   0.131920   0.214309  0.562290
# 18                8                    90   0.212473   0.163115  0.541246
# 19                2                    95   0.704862   0.289790  0.487374
# 20                8                    92   0.231374   0.180281  0.475589
# 21               32                    95   0.081968   0.281412  0.456229
# 22               16                    95   0.155341   0.245810  0.407407
# 23                4                    95   0.414432   0.245283  0.404882
# 24                2                    97   0.825295   0.366209  0.359428
# 25                8                    95   0.271379   0.214135  0.341751
# 26               32                    97   0.100590   0.342711  0.338384
# 27               16                    97   0.182901   0.283570  0.286195
# 28                4                    97   0.489136   0.259442  0.265993
# 29                8                    97   0.318475   0.256191  0.252525
# 30                2                    99   1.157636   0.568000  0.179293
# 31               32                    99   0.151264   0.476684  0.154882
# 32               16                    99   0.250934   0.348946  0.125421
# 33                4                    99   0.666744   0.385417  0.124579
# 34                8                    99   0.433520   0.308824  0.106061
#
#           f1       fpr       fnr
# 0   0.233020  0.181658  0.101852
# 1   0.225030  0.181289  0.138047
# 2   0.217804  0.181053  0.170034
# 3   0.273235  0.131553  0.175926
# 4   0.272933  0.129763  0.186027
# 5   0.210119  0.181921  0.199495
# 6   0.203648  0.182526  0.224747
# 7   0.255205  0.130842  0.241582
# 8   0.243745  0.133132  0.270202
# 9   0.330411  0.081500  0.286195
# 10  0.317793  0.082684  0.311448
# 11  0.222627  0.135553  0.331650
# 12  0.348384  0.063553  0.360269
# 13  0.295846  0.083184  0.364478
# 14  0.293585  0.082842  0.372054
# 15  0.322061  0.064711  0.410774
# 16  0.315765  0.064605  0.425084
# 17  0.310337  0.064447  0.437710
# 18  0.250682  0.086816  0.458754
# 19  0.363465  0.037342  0.512626
# 20  0.261453  0.067605  0.524411
# 21  0.348105  0.036421  0.543771
# 22  0.306620  0.039079  0.592593
# 23  0.305494  0.038947  0.595118
# 24  0.362787  0.019447  0.640572
# 25  0.263294  0.039211  0.658249
# 26  0.340534  0.020289  0.661616
# 27  0.284876  0.022605  0.713805
# 28  0.262677  0.023737  0.734007
# 29  0.254345  0.022921  0.747475
# 30  0.272553  0.004263  0.820707
# 31  0.233799  0.005316  0.845118
# 32  0.184520  0.007316  0.874579
# 33  0.188295  0.006211  0.875421
# 34  0.157895  0.007421  0.893939
# Final engineered-feature autoencoder test: bottleneck=4, percentile=85
#   Precision=0.1586, Recall=0.8047, F1=0.2650, FPR=0.1335, FNR=0.1953
#   ROC-AUC=0.9174, PR-AUC=0.2459
#   Confusion matrix [[TP, FP], [FN, TN]]:
# [[  956  5072]
#  [  232 32928]]
#   brute_force detection rate: 0.6723
#   ddos detection rate: 0.8697
#   dns_spoofing detection rate: 0.7004
#   dos detection rate: 0.8782
#   xss detection rate: 0.9030

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, precision_recall_curve

# Step 4: Plot test ROC and precision-recall curves for the engineered-feature rerun.
brute_test_truth = y_brute_test != "benign"

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

for name, scores in [
    ("Engineered K-means", brute_kmeans_test_scores),
    ("Engineered Autoencoder", brute_ae_test_scores),
]:
    fpr_curve, tpr_curve, _ = roc_curve(brute_test_truth, scores)
    curve_precision, curve_recall, _ = precision_recall_curve(brute_test_truth, scores)
    axes[0].plot(fpr_curve, tpr_curve, label=name)
    axes[1].plot(curve_recall, curve_precision, label=name)

axes[0].plot([0, 1], [0, 1], "--", color="gray")
axes[0].set(title="Engineered Feature Test ROC Curve", xlabel="False Positive Rate", ylabel="True Positive Rate")
axes[1].set(title="Engineered Feature Test Precision-Recall Curve", xlabel="Recall", ylabel="Precision")
for axis in axes:
    axis.grid(alpha=0.3)
    axis.legend()
plt.tight_layout()
plt.show()
