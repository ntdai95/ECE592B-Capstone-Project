# %% [markdown]
# # Data Preparation & Initialization

# %% [markdown]
# ### Set Gobal Seed

# %%
Seed = 1

# %% [markdown]
# ### Import Data

# %%
import pandas as pd

df = pd.read_csv("packet-data/for_data.csv")

df.head()
# Out:
#    channel_10_count  channel_10_mean  channel_10_var  channel_1_count  \
# 0         -1.581537        -0.842522        0.771697        -1.311927
# 1         -0.263427        -0.762558       -0.361727        -0.341756
# 2         -0.807535        -0.435740        0.300755        -0.720894
# 3         -0.191515        -0.885359       -1.022789        -1.050391
# 4          0.192499        -0.834817       -1.149986        -0.417729
#
#    channel_1_mean  channel_1_var  channel_30_count  channel_30_mean  \
# 0       -0.811524      -1.431741         -1.826406        -0.842090
# 1       -0.750308      -0.064285          0.143060        -0.774783
# 2       -0.442117       0.570058         -0.589184        -0.439128
# 3       -0.784083      -0.054231         -0.034582        -0.866827
# 4       -0.797050      -0.481221          0.047961        -0.832411
#
#    channel_30_var  channel_5_count  ...  stream_unique_dst_ips_seen_so_far  \
# 0        0.786877        -1.494342  ...                          -1.827695
# 1       -0.462200        -0.454379  ...                          -1.827695
# 2        0.273772        -0.663654  ...                          -1.827695
# 3       -0.443953        -0.233760  ...                          -1.827695
# 4       -1.139740         0.051862  ...                          -1.326492
#
#    stream_unique_dst_ports_seen_so_far     sum_p  tcp_window_size  \
# 0                            -1.673529 -0.779439        -1.432806
# 1                            -1.673529 -0.558099         0.907656
# 2                            -1.673529 -0.900192         0.290262
# 3                            -1.673529 -0.379196        -1.432806
# 4                            -1.673529 -0.880612        -1.432806
#
#    time_since_previously_displayed_frame       ttl  uri_special_chars  \
# 0                               0.011012 -0.530232          -0.057043
# 1                               0.002189 -0.579482          -0.057043
# 2                              -0.011846 -0.530232          -0.057043
# 3                              -0.011856 -1.318230          -0.057043
# 4                               0.030819 -0.530232          -0.057043
#
#       var_p  id   label
# 0 -0.803359   0  benign
# 1 -0.639181   1  benign
# 2 -0.670437   2  benign
# 3 -0.042758   4  benign
# 4 -1.253344   5  benign
#
# [5 rows x 128 columns]

# %% [markdown]
# ### Drop Variables Not Used
# - Drop "id" column

# %%
# Preserve IDs for linking Phase 2 alerts to Phase 3 flow records.
packet_ids = df["id"].copy() if "id" in df.columns else pd.Series(df.index)

# ID is an identifier, not a behavioral feature.
df = df.drop(columns=["id"], errors="ignore")

df.head()
# Out:
#    channel_10_count  channel_10_mean  channel_10_var  channel_1_count  \
# 0         -1.581537        -0.842522        0.771697        -1.311927
# 1         -0.263427        -0.762558       -0.361727        -0.341756
# 2         -0.807535        -0.435740        0.300755        -0.720894
# 3         -0.191515        -0.885359       -1.022789        -1.050391
# 4          0.192499        -0.834817       -1.149986        -0.417729
#
#    channel_1_mean  channel_1_var  channel_30_count  channel_30_mean  \
# 0       -0.811524      -1.431741         -1.826406        -0.842090
# 1       -0.750308      -0.064285          0.143060        -0.774783
# 2       -0.442117       0.570058         -0.589184        -0.439128
# 3       -0.784083      -0.054231         -0.034582        -0.866827
# 4       -0.797050      -0.481221          0.047961        -0.832411
#
#    channel_30_var  channel_5_count  ...  stream_rate_5  \
# 0        0.786877        -1.494342  ...      -1.194937
# 1       -0.462200        -0.454379  ...      -0.473560
# 2        0.273772        -0.663654  ...      -0.941186
# 3       -0.443953        -0.233760  ...      -0.091238
# 4       -1.139740         0.051862  ...       0.131979
#
#    stream_unique_dst_ips_seen_so_far  stream_unique_dst_ports_seen_so_far  \
# 0                          -1.827695                            -1.673529
# 1                          -1.827695                            -1.673529
# 2                          -1.827695                            -1.673529
# 3                          -1.827695                            -1.673529
# 4                          -1.326492                            -1.673529
#
#       sum_p  tcp_window_size  time_since_previously_displayed_frame       ttl  \
# 0 -0.779439        -1.432806                               0.011012 -0.530232
# 1 -0.558099         0.907656                               0.002189 -0.579482
# 2 -0.900192         0.290262                              -0.011846 -0.530232
# 3 -0.379196        -1.432806                              -0.011856 -1.318230
# 4 -0.880612        -1.432806                               0.030819 -0.530232
#
#    uri_special_chars     var_p   label
# 0          -0.057043 -0.803359  benign
# 1          -0.057043 -0.639181  benign
# 2          -0.057043 -0.670437  benign
# 3          -0.057043 -0.042758  benign
# 4          -0.057043 -1.253344  benign
#
# [5 rows x 127 columns]

# %% [markdown]
# ### Create Data Matrix and Label Vector

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Separate labels for stratification and evaluation; labels are never passed to fit().
X = df.drop(columns=["label"]).to_numpy()
y = df["label"].to_numpy()

print("Data matrix shape:", X.shape)
print("Label vector shape:", y.shape)

row_indices = np.arange(X.shape[0])
X_train, X_remaining, y_train, y_remaining, index_train, index_remaining = train_test_split(
    X, y, row_indices, test_size=0.4, stratify=y, random_state=Seed
)
X_validation, X_test, y_validation, y_test, index_validation, index_test = train_test_split(
    X_remaining,
    y_remaining,
    index_remaining,
    test_size=0.5,
    stratify=y_remaining,
    random_state=Seed,
)

# Fit preprocessing only on the training partition.
phase2_scaler = StandardScaler()
X_train_scaled = phase2_scaler.fit_transform(X_train)
X_validation_scaled = phase2_scaler.transform(X_validation)
X_test_scaled = phase2_scaler.transform(X_test)

print("Train/validation/test sizes:", X_train.shape[0], X_validation.shape[0], X_test.shape[0])
print("Training labels are retained only for analysis, not model fitting.")
# Out:
# Data matrix shape: (195940, 126)
# Label vector shape: (195940,)
# Train/validation/test sizes: 117564 39188 39188
# Training labels are retained only for analysis, not model fitting.

# %% [markdown]
# # K-means (high-recall alert generator)

# %% [markdown]
# ### K-means Hyperparameters Tuning
# - Hyperparameters:
#     - K: number of clusters used to represent benign behaviour
#     - Threshold_percentile: distance cutoff for classifying a sample as anomalous
#
# - Model selection uses validation results
#     - recall >= 0.9 and FPR <= 0.15
#     - if non qualify
#     - keep configuration with FPR <= 0.15

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (precision_score, recall_score, f1_score, confusion_matrix,
                             roc_auc_score, average_precision_score)

k_values = [2, 4, 6, 8, 10, 15, 20, 40, 50, 60, 80, 100]
threshold_percentiles = [80, 85, 90, 92, 95, 97, 99]

# Fit K-means on unlabeled training features; labels are used only for validation.
X_kmeans_train = X_train_scaled
X_evaluation = X_validation_scaled
y_evaluation = y_validation
y_attack = y_validation[y_validation != "benign"]
true_attack = y_evaluation != "benign"

models = {}
thresholds = {}
inertias = []
kmeans_results = []

for k in k_values:
    model = KMeans(
        n_clusters=k,
        init="k-means++",
        n_init=5,
        random_state=Seed,
    )
    model.fit(X_kmeans_train)

    # A sample is anomalous when its nearest-centroid distance exceeds
    # the chosen percentile of benign training distances.
    training_distances = model.transform(X_kmeans_train).min(axis=1)
    evaluation_distances = model.transform(X_evaluation).min(axis=1)

    models[k] = model
    inertias.append(model.inertia_)

    for percentile in threshold_percentiles:
        threshold = np.percentile(training_distances, percentile)
        predicted_attack = evaluation_distances > threshold

        precision = precision_score(true_attack, predicted_attack, zero_division=0)
        recall = recall_score(true_attack, predicted_attack, zero_division=0)
        f1 = f1_score(true_attack, predicted_attack, zero_division=0)
        tn, fp, fn, tp = confusion_matrix(
            true_attack, predicted_attack, labels=[False, True]
        ).ravel()
        fpr = fp / (fp + tn) if (fp + tn) else 0.0
        fnr = fn / (fn + tp) if (fn + tp) else 0.0

        thresholds[(k, percentile)] = threshold
        kmeans_results.append({
            "k": k,
            "threshold_percentile": percentile,
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "fpr": fpr,
            "fnr": fnr,
        })

        print(
            f"k={k}, percentile={percentile}: Precision={precision:.4f}, "
            f"Recall={recall:.4f}, F1={f1:.4f}"
        )
        print("  Confusion matrix [[TP, FP], [FN, TN]]:")
        print("  Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]")
        print(np.array([[tp, fp], [fn, tn]]))
        for attack in sorted(np.unique(y_attack)):
            attack_mask = y_evaluation == attack
            detection_rate = predicted_attack[attack_mask].mean()
            print(f"  {attack} detection rate: {detection_rate:.4f}")

kmeans_results_df = pd.DataFrame(kmeans_results)
display(
    kmeans_results_df.sort_values("fnr", ascending=True).reset_index(drop=True)
)

# Prefer high recall for Phase 2, while limiting validation false alarms.
eligible_kmeans = kmeans_results_df[
    (kmeans_results_df["recall"] >= 0.90) & (kmeans_results_df["fpr"] <= 0.15)
]
if eligible_kmeans.empty:
    eligible_kmeans = kmeans_results_df[kmeans_results_df["fpr"] <= 0.15]
if eligible_kmeans.empty:
    eligible_kmeans = kmeans_results_df
best_kmeans_config = eligible_kmeans.sort_values(
    ["fnr", "fpr", "f1"], ascending=[True, True, False]
).iloc[0]

best_k = int(best_kmeans_config["k"])
best_kmeans_percentile = int(best_kmeans_config["threshold_percentile"])
best_kmeans_model = models[best_k]
best_kmeans_threshold = thresholds[(best_k, best_kmeans_percentile)]
kmeans_test_scores = best_kmeans_model.transform(X_test_scaled).min(axis=1)
kmeans_test_predictions = kmeans_test_scores > best_kmeans_threshold
kmeans_test_truth = y_test != "benign"
kmeans_test_precision = precision_score(kmeans_test_truth, kmeans_test_predictions, zero_division=0)
kmeans_test_recall = recall_score(kmeans_test_truth, kmeans_test_predictions, zero_division=0)
kmeans_test_f1 = f1_score(kmeans_test_truth, kmeans_test_predictions, zero_division=0)
kmeans_tn, kmeans_fp, kmeans_fn, kmeans_tp = confusion_matrix(
    kmeans_test_truth, kmeans_test_predictions, labels=[False, True]
).ravel()
kmeans_test_fpr = kmeans_fp / (kmeans_fp + kmeans_tn)
kmeans_test_fnr = kmeans_fn / (kmeans_fn + kmeans_tp)
kmeans_test_roc_auc = roc_auc_score(kmeans_test_truth, kmeans_test_scores)
kmeans_test_pr_auc = average_precision_score(kmeans_test_truth, kmeans_test_scores)
print(
    f"Final K-means test: k={best_k}, percentile={best_kmeans_percentile}, "
    f"Precision={kmeans_test_precision:.4f}, Recall={kmeans_test_recall:.4f}, "
    f"F1={kmeans_test_f1:.4f}, FPR={kmeans_test_fpr:.4f}, "
    f"FNR={kmeans_test_fnr:.4f}, ROC-AUC={kmeans_test_roc_auc:.4f}, "
    f"PR-AUC={kmeans_test_pr_auc:.4f}"
)
print(np.array([[kmeans_tp, kmeans_fp], [kmeans_fn, kmeans_tn]]))
for attack in sorted(np.unique(y_test[y_test != "benign"])):
    attack_mask = y_test == attack
    print(f"  {attack} detection rate: {kmeans_test_predictions[attack_mask].mean():.4f}")

kmeans_alerts_df = pd.DataFrame({
    "packet_id": packet_ids.iloc[index_test].to_numpy(),
    "true_label": y_test,
    "anomaly_score": kmeans_test_scores,
    "alert": kmeans_test_predictions,
})
kmeans_alerts_df = kmeans_alerts_df[kmeans_alerts_df["alert"]].reset_index(drop=True)
# Out:
# k=2, percentile=80: Precision=0.1112, Recall=0.7205, F1=0.1927
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  856  6839]
#  [  332 31161]]
#   brute_force detection rate: 0.7468
#   ddos detection rate: 0.9831
#   dns_spoofing detection rate: 0.4370
#   dos detection rate: 0.9454
#   xss detection rate: 0.4916
# k=2, percentile=85: Precision=0.1345, Recall=0.6599, F1=0.2235
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  784  5044]
#  [  404 32956]]
#   brute_force detection rate: 0.6709
#   ddos detection rate: 0.9831
#   dns_spoofing detection rate: 0.3235
#   dos detection rate: 0.9034
#   xss detection rate: 0.4202
# k=2, percentile=90: Precision=0.1719, Recall=0.5614, F1=0.2632
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  667  3213]
#  [  521 34787]]
#   brute_force detection rate: 0.4810
#   ddos detection rate: 0.9578
#   dns_spoofing detection rate: 0.1975
#   dos detection rate: 0.8319
#   xss detection rate: 0.3403
# k=2, percentile=92: Precision=0.1866, Recall=0.4874, F1=0.2699
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  579  2524]
#  [  609 35476]]
#   brute_force detection rate: 0.3207
#   ddos detection rate: 0.8650
#   dns_spoofing detection rate: 0.1387
#   dos detection rate: 0.7941
#   xss detection rate: 0.3193
# k=2, percentile=95: Precision=0.2153, Recall=0.3502, F1=0.2667
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  416  1516]
#  [  772 36484]]
#   brute_force detection rate: 0.1139
#   ddos detection rate: 0.5696
#   dns_spoofing detection rate: 0.0714
#   dos detection rate: 0.7269
#   xss detection rate: 0.2689
# k=2, percentile=97: Precision=0.2472, Recall=0.2424, F1=0.2448
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  288   877]
#  [  900 37123]]
#   brute_force detection rate: 0.0759
#   ddos detection rate: 0.2785
#   dns_spoofing detection rate: 0.0294
#   dos detection rate: 0.6345
#   xss detection rate: 0.1933
# k=2, percentile=99: Precision=0.1378, Recall=0.0455, F1=0.0684
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   54   338]
#  [ 1134 37662]]
#   brute_force detection rate: 0.0549
#   ddos detection rate: 0.0000
#   dns_spoofing detection rate: 0.0000
#   dos detection rate: 0.0000
#   xss detection rate: 0.1723
# k=4, percentile=80: Precision=0.1226, Recall=0.8089, F1=0.2129
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  961  6879]
#  [  227 31121]]
#   brute_force detection rate: 0.8650
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.5126
#   dos detection rate: 1.0000
#   xss detection rate: 0.6681
# k=4, percentile=85: Precision=0.1539, Recall=0.7508, F1=0.2555
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  892  4903]
#  [  296 33097]]
#   brute_force detection rate: 0.7722
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.4328
#   dos detection rate: 0.9958
#   xss detection rate: 0.5546
# k=4, percentile=90: Precision=0.2021, Recall=0.6540, F1=0.3088
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  777  3068]
#  [  411 34932]]
#   brute_force detection rate: 0.5992
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.2857
#   dos detection rate: 0.9538
#   xss detection rate: 0.4328
# k=4, percentile=92: Precision=0.2201, Recall=0.5707, F1=0.3177
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  678  2402]
#  [  510 35598]]
#   brute_force detection rate: 0.4599
#   ddos detection rate: 0.9831
#   dns_spoofing detection rate: 0.1429
#   dos detection rate: 0.8908
#   xss detection rate: 0.3782
# k=4, percentile=95: Precision=0.2393, Recall=0.3847, F1=0.2950
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  457  1453]
#  [  731 36547]]
#   brute_force detection rate: 0.1350
#   ddos detection rate: 0.7257
#   dns_spoofing detection rate: 0.0336
#   dos detection rate: 0.7521
#   xss detection rate: 0.2773
# k=4, percentile=97: Precision=0.2753, Recall=0.2677, F1=0.2714
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  318   837]
#  [  870 37163]]
#   brute_force detection rate: 0.0802
#   ddos detection rate: 0.4473
#   dns_spoofing detection rate: 0.0168
#   dos detection rate: 0.5924
#   xss detection rate: 0.2017
# k=4, percentile=99: Precision=0.1462, Recall=0.0480, F1=0.0722
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   57   333]
#  [ 1131 37667]]
#   brute_force detection rate: 0.0591
#   ddos detection rate: 0.0000
#   dns_spoofing detection rate: 0.0000
#   dos detection rate: 0.0042
#   xss detection rate: 0.1765
# k=6, percentile=80: Precision=0.1298, Recall=0.8704, F1=0.2259
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[ 1034  6934]
#  [  154 31066]]
#   brute_force detection rate: 0.8945
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.6134
#   dos detection rate: 1.0000
#   xss detection rate: 0.8445
# k=6, percentile=85: Precision=0.1626, Recall=0.8131, F1=0.2710
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  966  4976]
#  [  222 33024]]
#   brute_force detection rate: 0.8228
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.5252
#   dos detection rate: 1.0000
#   xss detection rate: 0.7185
# k=6, percentile=90: Precision=0.2213, Recall=0.7340, F1=0.3400
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  872  3069]
#  [  316 34931]]
#   brute_force detection rate: 0.6456
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.4496
#   dos detection rate: 1.0000
#   xss detection rate: 0.5798
# k=6, percentile=92: Precision=0.2571, Recall=0.6818, F1=0.3734
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  810  2340]
#  [  378 35660]]
#   brute_force detection rate: 0.4979
#   ddos detection rate: 0.9916
#   dns_spoofing detection rate: 0.3655
#   dos detection rate: 0.9916
#   xss detection rate: 0.5630
# k=6, percentile=95: Precision=0.3359, Recall=0.5488, F1=0.4167
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  652  1289]
#  [  536 36711]]
#   brute_force detection rate: 0.2616
#   ddos detection rate: 0.9620
#   dns_spoofing detection rate: 0.1765
#   dos detection rate: 0.9328
#   xss detection rate: 0.4118
# k=6, percentile=97: Precision=0.4074, Recall=0.4057, F1=0.4066
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  482   701]
#  [  706 37299]]
#   brute_force detection rate: 0.0886
#   ddos detection rate: 0.8565
#   dns_spoofing detection rate: 0.0252
#   dos detection rate: 0.7857
#   xss detection rate: 0.2731
# k=6, percentile=99: Precision=0.1750, Recall=0.0589, F1=0.0882
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   70   330]
#  [ 1118 37670]]
#   brute_force detection rate: 0.0591
#   ddos detection rate: 0.0127
#   dns_spoofing detection rate: 0.0168
#   dos detection rate: 0.0252
#   xss detection rate: 0.1807
# k=8, percentile=80: Precision=0.1283, Recall=0.8611, F1=0.2233
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[ 1023  6951]
#  [  165 31049]]
#   brute_force detection rate: 0.8987
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.6176
#   dos detection rate: 1.0000
#   xss detection rate: 0.7899
# k=8, percentile=85: Precision=0.1644, Recall=0.8232, F1=0.2741
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  978  4971]
#  [  210 33029]]
#   brute_force detection rate: 0.8650
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.5420
#   dos detection rate: 1.0000
#   xss detection rate: 0.7101
# k=8, percentile=90: Precision=0.2288, Recall=0.7643, F1=0.3522
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  908  3060]
#  [  280 34940]]
#   brute_force detection rate: 0.7553
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.4664
#   dos detection rate: 1.0000
#   xss detection rate: 0.6050
# k=8, percentile=92: Precision=0.2686, Recall=0.7130, F1=0.3902
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  847  2306]
#  [  341 35694]]
#   brute_force detection rate: 0.6034
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.3866
#   dos detection rate: 1.0000
#   xss detection rate: 0.5798
# k=8, percentile=95: Precision=0.3484, Recall=0.5774, F1=0.4346
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  686  1283]
#  [  502 36717]]
#   brute_force detection rate: 0.2996
#   ddos detection rate: 0.9831
#   dns_spoofing detection rate: 0.1681
#   dos detection rate: 0.9706
#   xss detection rate: 0.4664
# k=8, percentile=97: Precision=0.4375, Recall=0.4360, F1=0.4368
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  518   666]
#  [  670 37334]]
#   brute_force detection rate: 0.0886
#   ddos detection rate: 0.9241
#   dns_spoofing detection rate: 0.0210
#   dos detection rate: 0.8403
#   xss detection rate: 0.3067
# k=8, percentile=99: Precision=0.1787, Recall=0.0606, F1=0.0905
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   72   331]
#  [ 1116 37669]]
#   brute_force detection rate: 0.0591
#   ddos detection rate: 0.0169
#   dns_spoofing detection rate: 0.0168
#   dos detection rate: 0.0294
#   xss detection rate: 0.1807
# k=10, percentile=80: Precision=0.1289, Recall=0.8670, F1=0.2245
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[ 1030  6958]
#  [  158 31042]]
#   brute_force detection rate: 0.9367
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.6008
#   dos detection rate: 1.0000
#   xss detection rate: 0.7983
# k=10, percentile=85: Precision=0.1636, Recall=0.8199, F1=0.2728
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  974  4980]
#  [  214 33020]]
#   brute_force detection rate: 0.8776
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.5504
#   dos detection rate: 1.0000
#   xss detection rate: 0.6723
# k=10, percentile=90: Precision=0.2242, Recall=0.7424, F1=0.3444
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  882  3052]
#  [  306 34948]]
#   brute_force detection rate: 0.6751
#   ddos detection rate: 1.0000
#   dns_spoofing detection rate: 0.4370
#   dos detection rate: 1.0000
#   xss detection rate: 0.6008
# k=10, percentile=92: Precision=0.2653, Recall=0.6987, F1=0.3845
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  830  2299]
#  [  358 35701]]
#   brute_force detection rate: 0.5654
#   ddos detection rate: 0.9916
#   dns_spoofing detection rate: 0.3739
#   dos detection rate: 0.9958
#   xss detection rate: 0.5672
# k=10, percentile=95: Precision=0.3666, Recall=0.6002, F1=0.4552
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  713  1232]
#  [  475 36768]]
#   brute_force detection rate: 0.3249
#   ddos detection rate: 0.9747
#   dns_spoofing detection rate: 0.1975
#   dos detection rate: 0.9706
#   xss detection rate: 0.5336
# k=10, percentile=97: Precision=0.4658, Recall=0.4697, F1=0.4677
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  558   640]
#  [  630 37360]]
#   brute_force detection rate: 0.1603
#   ddos detection rate: 0.9325
#   dns_spoofing detection rate: 0.0462
#   dos detection rate: 0.8655
#   xss detection rate: 0.3445
# k=10, percentile=99: Precision=0.4667, Recall=0.1532, F1=0.2307
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  182   208]
#  [ 1006 37792]]
#   brute_force detection rate: 0.0591
#   ddos detection rate: 0.1477
#   dns_spoofing detection rate: 0.0168
#   dos detection rate: 0.3992
#   xss detection rate: 0.1429
# k=15, percentile=80: Precision=0.1298, Recall=0.8603, F1=0.2256
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[ 1022  6850]
#  [  166 31150]]
#   brute_force detection rate: 0.9367
#   ddos detection rate: 0.8228
#   dns_spoofing detection rate: 0.6807
#   dos detection rate: 0.9622
#   xss detection rate: 0.8992
# k=15, percentile=85: Precision=0.1531, Recall=0.7576, F1=0.2547
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  900  4978]
#  [  288 33022]]
#   brute_force detection rate: 0.8903
#   ddos detection rate: 0.6962
#   dns_spoofing detection rate: 0.5630
#   dos detection rate: 0.8445
#   xss detection rate: 0.7941
# k=15, percentile=90: Precision=0.1809, Recall=0.6010, F1=0.2780
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  714  3234]
#  [  474 34766]]
#   brute_force detection rate: 0.7426
#   ddos detection rate: 0.5907
#   dns_spoofing detection rate: 0.4076
#   dos detection rate: 0.6134
#   xss detection rate: 0.6513
# k=15, percentile=92: Precision=0.1964, Recall=0.5194, F1=0.2851
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  617  2524]
#  [  571 35476]]
#   brute_force detection rate: 0.6498
#   ddos detection rate: 0.5190
#   dns_spoofing detection rate: 0.3529
#   dos detection rate: 0.4832
#   xss detection rate: 0.5924
# k=15, percentile=95: Precision=0.1964, Recall=0.3232, F1=0.2444
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  384  1571]
#  [  804 36429]]
#   brute_force detection rate: 0.3755
#   ddos detection rate: 0.2827
#   dns_spoofing detection rate: 0.1891
#   dos detection rate: 0.2395
#   xss detection rate: 0.5294
# k=15, percentile=97: Precision=0.1598, Recall=0.1557, F1=0.1577
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  185   973]
#  [ 1003 37027]]
#   brute_force detection rate: 0.1392
#   ddos detection rate: 0.0928
#   dns_spoofing detection rate: 0.0546
#   dos detection rate: 0.0672
#   xss detection rate: 0.4244
# k=15, percentile=99: Precision=0.1521, Recall=0.0513, F1=0.0768
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   61   340]
#  [ 1127 37660]]
#   brute_force detection rate: 0.0591
#   ddos detection rate: 0.0000
#   dns_spoofing detection rate: 0.0168
#   dos detection rate: 0.0000
#   xss detection rate: 0.1807
# k=20, percentile=80: Precision=0.1320, Recall=0.8788, F1=0.2295
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[ 1044  6865]
#  [  144 31135]]
#   brute_force detection rate: 0.9072
#   ddos detection rate: 0.8692
#   dns_spoofing detection rate: 0.7269
#   dos detection rate: 0.9790
#   xss detection rate: 0.9118
# k=20, percentile=85: Precision=0.1543, Recall=0.7744, F1=0.2573
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  920  5042]
#  [  268 32958]]
#   brute_force detection rate: 0.8143
#   ddos detection rate: 0.7468
#   dns_spoofing detection rate: 0.5882
#   dos detection rate: 0.9034
#   xss detection rate: 0.8193
# k=20, percentile=90: Precision=0.1784, Recall=0.5901, F1=0.2740
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  701  3228]
#  [  487 34772]]
#   brute_force detection rate: 0.5865
#   ddos detection rate: 0.5992
#   dns_spoofing detection rate: 0.4160
#   dos detection rate: 0.6849
#   xss detection rate: 0.6639
# k=20, percentile=92: Precision=0.1958, Recall=0.5227, F1=0.2849
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  621  2551]
#  [  567 35449]]
#   brute_force detection rate: 0.5021
#   ddos detection rate: 0.5696
#   dns_spoofing detection rate: 0.3824
#   dos detection rate: 0.5546
#   xss detection rate: 0.6050
# k=20, percentile=95: Precision=0.2185, Recall=0.3586, F1=0.2715
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  426  1524]
#  [  762 36476]]
#   brute_force detection rate: 0.3291
#   ddos detection rate: 0.3882
#   dns_spoofing detection rate: 0.2479
#   dos detection rate: 0.2773
#   xss detection rate: 0.5504
# k=20, percentile=97: Precision=0.2290, Recall=0.2273, F1=0.2281
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  270   909]
#  [  918 37091]]
#   brute_force detection rate: 0.2025
#   ddos detection rate: 0.1772
#   dns_spoofing detection rate: 0.1134
#   dos detection rate: 0.1387
#   xss detection rate: 0.5042
# k=20, percentile=99: Precision=0.2203, Recall=0.0766, F1=0.1137
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   91   322]
#  [ 1097 37678]]
#   brute_force detection rate: 0.0633
#   ddos detection rate: 0.0211
#   dns_spoofing detection rate: 0.0210
#   dos detection rate: 0.0042
#   xss detection rate: 0.2731
# k=40, percentile=80: Precision=0.1255, Recall=0.8409, F1=0.2184
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  999  6962]
#  [  189 31038]]
#   brute_force detection rate: 0.9114
#   ddos detection rate: 0.9283
#   dns_spoofing detection rate: 0.6134
#   dos detection rate: 0.8025
#   xss detection rate: 0.9496
# k=40, percentile=85: Precision=0.1421, Recall=0.7113, F1=0.2369
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  845  5101]
#  [  343 32899]]
#   brute_force detection rate: 0.7553
#   ddos detection rate: 0.8017
#   dns_spoofing detection rate: 0.4832
#   dos detection rate: 0.6723
#   xss detection rate: 0.8445
# k=40, percentile=90: Precision=0.1616, Recall=0.5387, F1=0.2486
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  640  3321]
#  [  548 34679]]
#   brute_force detection rate: 0.5570
#   ddos detection rate: 0.5907
#   dns_spoofing detection rate: 0.3529
#   dos detection rate: 0.5252
#   xss detection rate: 0.6681
# k=40, percentile=92: Precision=0.1661, Recall=0.4419, F1=0.2414
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  525  2636]
#  [  663 35364]]
#   brute_force detection rate: 0.4093
#   ddos detection rate: 0.4430
#   dns_spoofing detection rate: 0.2689
#   dos detection rate: 0.4790
#   xss detection rate: 0.6092
# k=40, percentile=95: Precision=0.1806, Recall=0.2963, F1=0.2244
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  352  1597]
#  [  836 36403]]
#   brute_force detection rate: 0.2321
#   ddos detection rate: 0.2236
#   dns_spoofing detection rate: 0.1765
#   dos detection rate: 0.3445
#   xss detection rate: 0.5042
# k=40, percentile=97: Precision=0.2054, Recall=0.1995, F1=0.2024
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  237   917]
#  [  951 37083]]
#   brute_force detection rate: 0.1181
#   ddos detection rate: 0.1139
#   dns_spoofing detection rate: 0.1092
#   dos detection rate: 0.2059
#   xss detection rate: 0.4496
# k=40, percentile=99: Precision=0.2015, Recall=0.0682, F1=0.1019
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   81   321]
#  [ 1107 37679]]
#   brute_force detection rate: 0.0464
#   ddos detection rate: 0.0380
#   dns_spoofing detection rate: 0.0042
#   dos detection rate: 0.0210
#   xss detection rate: 0.2311
# k=50, percentile=80: Precision=0.1371, Recall=0.9200, F1=0.2387
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[ 1093  6877]
#  [   95 31123]]
#   brute_force detection rate: 0.9705
#   ddos detection rate: 0.9958
#   dns_spoofing detection rate: 0.7353
#   dos detection rate: 1.0000
#   xss detection rate: 0.8992
# k=50, percentile=85: Precision=0.1747, Recall=0.8763, F1=0.2913
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[ 1041  4918]
#  [  147 33082]]
#   brute_force detection rate: 0.9536
#   ddos detection rate: 0.9831
#   dns_spoofing detection rate: 0.6471
#   dos detection rate: 0.9958
#   xss detection rate: 0.8025
# k=50, percentile=90: Precision=0.2358, Recall=0.7837, F1=0.3625
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  931  3018]
#  [  257 34982]]
#   brute_force detection rate: 0.8987
#   ddos detection rate: 0.8650
#   dns_spoofing detection rate: 0.5084
#   dos detection rate: 0.9706
#   xss detection rate: 0.6765
# k=50, percentile=92: Precision=0.2689, Recall=0.7273, F1=0.3926
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  864  2349]
#  [  324 35651]]
#   brute_force detection rate: 0.8481
#   ddos detection rate: 0.7806
#   dns_spoofing detection rate: 0.4538
#   dos detection rate: 0.9286
#   xss detection rate: 0.6261
# k=50, percentile=95: Precision=0.3510, Recall=0.5783, F1=0.4369
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  687  1270]
#  [  501 36730]]
#   brute_force detection rate: 0.6920
#   ddos detection rate: 0.6076
#   dns_spoofing detection rate: 0.3067
#   dos detection rate: 0.7143
#   xss detection rate: 0.5714
# k=50, percentile=97: Precision=0.4162, Recall=0.4116, F1=0.4139
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  489   686]
#  [  699 37314]]
#   brute_force detection rate: 0.4473
#   ddos detection rate: 0.5148
#   dns_spoofing detection rate: 0.1723
#   dos detection rate: 0.4118
#   xss detection rate: 0.5126
# k=50, percentile=99: Precision=0.4674, Recall=0.1507, F1=0.2279
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  179   204]
#  [ 1009 37796]]
#   brute_force detection rate: 0.1055
#   ddos detection rate: 0.1941
#   dns_spoofing detection rate: 0.0084
#   dos detection rate: 0.1176
#   xss detection rate: 0.3277
# k=60, percentile=80: Precision=0.1178, Recall=0.7921, F1=0.2051
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  941  7049]
#  [  247 30951]]
#   brute_force detection rate: 0.8228
#   ddos detection rate: 0.9114
#   dns_spoofing detection rate: 0.6975
#   dos detection rate: 0.7899
#   xss detection rate: 0.7395
# k=60, percentile=85: Precision=0.1419, Recall=0.7130, F1=0.2367
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  847  5121]
#  [  341 32879]]
#   brute_force detection rate: 0.7553
#   ddos detection rate: 0.8228
#   dns_spoofing detection rate: 0.5882
#   dos detection rate: 0.7395
#   xss detection rate: 0.6597
# k=60, percentile=90: Precision=0.1682, Recall=0.5589, F1=0.2586
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  664  3284]
#  [  524 34716]]
#   brute_force detection rate: 0.5865
#   ddos detection rate: 0.6160
#   dns_spoofing detection rate: 0.4286
#   dos detection rate: 0.6513
#   xss detection rate: 0.5126
# k=60, percentile=92: Precision=0.1771, Recall=0.4705, F1=0.2574
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  559  2597]
#  [  629 35403]]
#   brute_force detection rate: 0.4979
#   ddos detection rate: 0.4810
#   dns_spoofing detection rate: 0.3529
#   dos detection rate: 0.5882
#   xss detection rate: 0.4328
# k=60, percentile=95: Precision=0.2049, Recall=0.3401, F1=0.2557
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  404  1568]
#  [  784 36432]]
#   brute_force detection rate: 0.3291
#   ddos detection rate: 0.3165
#   dns_spoofing detection rate: 0.2353
#   dos detection rate: 0.4916
#   xss detection rate: 0.3277
# k=60, percentile=97: Precision=0.2326, Recall=0.2281, F1=0.2303
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  271   894]
#  [  917 37106]]
#   brute_force detection rate: 0.1899
#   ddos detection rate: 0.1941
#   dns_spoofing detection rate: 0.1639
#   dos detection rate: 0.3697
#   xss detection rate: 0.2227
# k=60, percentile=99: Precision=0.2730, Recall=0.0901, F1=0.1354
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  107   285]
#  [ 1081 37715]]
#   brute_force detection rate: 0.0591
#   ddos detection rate: 0.0802
#   dns_spoofing detection rate: 0.0336
#   dos detection rate: 0.1261
#   xss detection rate: 0.1513
# k=80, percentile=80: Precision=0.1150, Recall=0.7668, F1=0.2000
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  911  7013]
#  [  277 30987]]
#   brute_force detection rate: 0.8354
#   ddos detection rate: 0.8776
#   dns_spoofing detection rate: 0.6597
#   dos detection rate: 0.6975
#   xss detection rate: 0.7647
# k=80, percentile=85: Precision=0.1283, Recall=0.6355, F1=0.2135
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  755  5128]
#  [  433 32872]]
#   brute_force detection rate: 0.7764
#   ddos detection rate: 0.6498
#   dns_spoofing detection rate: 0.5420
#   dos detection rate: 0.5588
#   xss detection rate: 0.6513
# k=80, percentile=90: Precision=0.1508, Recall=0.5008, F1=0.2318
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  595  3351]
#  [  593 34649]]
#   brute_force detection rate: 0.7004
#   ddos detection rate: 0.4810
#   dns_spoofing detection rate: 0.3908
#   dos detection rate: 0.4370
#   xss detection rate: 0.4958
# k=80, percentile=92: Precision=0.1607, Recall=0.4259, F1=0.2334
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  506  2642]
#  [  682 35358]]
#   brute_force detection rate: 0.5781
#   ddos detection rate: 0.4051
#   dns_spoofing detection rate: 0.3403
#   dos detection rate: 0.3824
#   xss detection rate: 0.4244
# k=80, percentile=95: Precision=0.1778, Recall=0.2912, F1=0.2208
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  346  1600]
#  [  842 36400]]
#   brute_force detection rate: 0.3966
#   ddos detection rate: 0.2911
#   dns_spoofing detection rate: 0.2059
#   dos detection rate: 0.2815
#   xss detection rate: 0.2815
# k=80, percentile=97: Precision=0.2032, Recall=0.2062, F1=0.2047
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  245   961]
#  [  943 37039]]
#   brute_force detection rate: 0.2447
#   ddos detection rate: 0.2110
#   dns_spoofing detection rate: 0.1387
#   dos detection rate: 0.2521
#   xss detection rate: 0.1849
# k=80, percentile=99: Precision=0.2178, Recall=0.0741, F1=0.1106
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   88   316]
#  [ 1100 37684]]
#   brute_force detection rate: 0.0928
#   ddos detection rate: 0.1013
#   dns_spoofing detection rate: 0.0378
#   dos detection rate: 0.0672
#   xss detection rate: 0.0714
# k=100, percentile=80: Precision=0.0982, Recall=0.6557, F1=0.1709
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  779  7152]
#  [  409 30848]]
#   brute_force detection rate: 0.4979
#   ddos detection rate: 0.4810
#   dns_spoofing detection rate: 0.6891
#   dos detection rate: 0.7857
#   xss detection rate: 0.8235
# k=100, percentile=85: Precision=0.1146, Recall=0.5606, F1=0.1903
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  666  5147]
#  [  522 32853]]
#   brute_force detection rate: 0.4515
#   ddos detection rate: 0.4135
#   dns_spoofing detection rate: 0.5966
#   dos detection rate: 0.6555
#   xss detection rate: 0.6849
# k=100, percentile=90: Precision=0.1271, Recall=0.4200, F1=0.1952
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  499  3427]
#  [  689 34573]]
#   brute_force detection rate: 0.3671
#   ddos detection rate: 0.2827
#   dns_spoofing detection rate: 0.4370
#   dos detection rate: 0.4664
#   xss detection rate: 0.5462
# k=100, percentile=92: Precision=0.1380, Recall=0.3662, F1=0.2005
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  435  2717]
#  [  753 35283]]
#   brute_force detection rate: 0.3207
#   ddos detection rate: 0.2574
#   dns_spoofing detection rate: 0.3697
#   dos detection rate: 0.3908
#   xss detection rate: 0.4916
# k=100, percentile=95: Precision=0.1639, Recall=0.2652, F1=0.2026
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  315  1607]
#  [  873 36393]]
#   brute_force detection rate: 0.2236
#   ddos detection rate: 0.1814
#   dns_spoofing detection rate: 0.2647
#   dos detection rate: 0.2731
#   xss detection rate: 0.3824
# k=100, percentile=97: Precision=0.1808, Recall=0.1742, F1=0.1775
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  207   938]
#  [  981 37062]]
#   brute_force detection rate: 0.1435
#   ddos detection rate: 0.0844
#   dns_spoofing detection rate: 0.1681
#   dos detection rate: 0.1555
#   xss detection rate: 0.3193
# k=100, percentile=99: Precision=0.2178, Recall=0.0699, F1=0.1058
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   83   298]
#  [ 1105 37702]]
#   brute_force detection rate: 0.0802
#   ddos detection rate: 0.0295
#   dns_spoofing detection rate: 0.0546
#   dos detection rate: 0.0336
#   xss detection rate: 0.1513
#      k  threshold_percentile  precision    recall        f1       fpr  \
# 0   50                    80   0.137139  0.920034  0.238698  0.180974
# 1   20                    80   0.132002  0.878788  0.229526  0.180658
# 2   50                    85   0.174694  0.876263  0.291311  0.129421
# 3    6                    80   0.129769  0.870370  0.225863  0.182474
# 4   10                    80   0.128943  0.867003  0.224499  0.183105
# ..  ..                   ...        ...       ...       ...       ...
# 79   8                    99   0.178660  0.060606  0.090509  0.008711
# 80   6                    99   0.175000  0.058923  0.088161  0.008684
# 81  15                    99   0.152120  0.051347  0.076778  0.008947
# 82   4                    99   0.146154  0.047980  0.072243  0.008763
# 83   2                    99   0.137755  0.045455  0.068354  0.008895
#
#          fnr
# 0   0.079966
# 1   0.121212
# 2   0.123737
# 3   0.129630
# 4   0.132997
# ..       ...
# 79  0.939394
# 80  0.941077
# 81  0.948653
# 82  0.952020
# 83  0.954545
#
# [84 rows x 7 columns]
# Final K-means test: k=50, percentile=85, Precision=0.1774, Recall=0.8687, F1=0.2946, FPR=0.1260, FNR=0.1313, ROC-AUC=0.9392, PR-AUC=0.3682
# [[ 1032  4787]
#  [  156 33213]]
#   brute_force detection rate: 0.9580
#   ddos detection rate: 0.9580
#   dns_spoofing detection rate: 0.6329
#   dos detection rate: 0.9874
#   xss detection rate: 0.8059

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 9))
axes = axes.ravel()

# Plot inertia to show how well the model fits the benign training data.
axes[0].plot(k_values, inertias, marker="o")
axes[0].set(title="Benign Training Inertia", xlabel="k", ylabel="Inertia")
axes[0].grid(alpha=0.3)

# Plot each metric for every threshold percentile.
for axis, metric, title in zip(
    axes[1:],
    ["precision", "recall", "f1", "fpr", "fnr"],
    ["Precision", "Recall", "F1 Score", "False Positive Rate", "False Negative Rate"],
):
    for percentile in threshold_percentiles:
        subset = kmeans_results_df[
            kmeans_results_df["threshold_percentile"] == percentile
        ].sort_values("k")
        axis.plot(
            subset["k"], subset[metric], marker="o", label=f"Percentile {percentile}"
        )
    axis.set(title=title, xlabel="k", ylabel="Score")
    axis.set_xticks(k_values)
    axis.grid(alpha=0.3)
    axis.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Autoencoders (high-recall alert generator)

# %% [markdown]
# ### Autoencoders Hyperparameters Tuning

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (precision_score, recall_score, f1_score, confusion_matrix,
                             roc_auc_score, average_precision_score)

keras.utils.set_random_seed(Seed)

bottleneck_sizes = [2, 4, 8, 16, 32]
threshold_percentiles = [80, 85, 90, 92, 95, 97, 99]

# Fit the autoencoder on unlabeled training features.
X_benign_train_ae = X_train_scaled.astype(np.float32)
X_evaluation_ae = X_validation_scaled.astype(np.float32)
y_evaluation_ae = y_validation
y_attack_ae = y_validation[y_validation != "benign"]
true_attack_ae = y_evaluation_ae != "benign"

input_dim = X_benign_train_ae.shape[1]
autoencoder_models = {}
ae_results = []

for bottleneck_size in bottleneck_sizes:
    keras.backend.clear_session()
    keras.utils.set_random_seed(Seed)

    inputs = keras.Input(shape=(input_dim,))
    encoded = keras.layers.Dense(64, activation="relu")(inputs)
    bottleneck = keras.layers.Dense(
        bottleneck_size, activation="relu", name="bottleneck"
    )(encoded)
    decoded = keras.layers.Dense(64, activation="relu")(bottleneck)
    outputs = keras.layers.Dense(input_dim)(decoded)
    autoencoder = keras.Model(inputs, outputs, name=f"autoencoder_{bottleneck_size}")
    autoencoder.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="mse",
    )

    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=5, restore_best_weights=True
    )
    history = autoencoder.fit(
        X_benign_train_ae,
        X_benign_train_ae,
        epochs=50,
        batch_size=512,
        validation_split=0.1,
        shuffle=True,
        callbacks=[early_stopping],
        verbose=0,
    )
    autoencoder_models[bottleneck_size] = autoencoder
    print(f"Bottleneck {bottleneck_size}: trained for {len(history.history['loss'])} epochs")

    train_reconstruction = autoencoder.predict(X_benign_train_ae, verbose=0)
    train_errors = np.mean(
        (X_benign_train_ae - train_reconstruction) ** 2, axis=1
    )
    evaluation_reconstruction = autoencoder.predict(X_evaluation_ae, verbose=0)
    evaluation_errors = np.mean(
        (X_evaluation_ae - evaluation_reconstruction) ** 2, axis=1
    )

    for percentile in threshold_percentiles:
        threshold = np.percentile(train_errors, percentile)
        predicted_attack = evaluation_errors > threshold

        precision = precision_score(
            true_attack_ae, predicted_attack, zero_division=0
        )
        f1 = f1_score(true_attack_ae, predicted_attack, zero_division=0)
        recall = recall_score(true_attack_ae, predicted_attack, zero_division=0)
        tn, fp, fn, tp = confusion_matrix(
            true_attack_ae, predicted_attack, labels=[False, True]
        ).ravel()
        fpr = fp / (fp + tn) if (fp + tn) else 0.0
        fnr = fn / (fn + tp) if (fn + tp) else 0.0

        result = {
            "bottleneck_size": bottleneck_size,
            "threshold_percentile": percentile,
            "threshold": threshold,
            "precision": precision,
            "f1": f1,
            "recall": recall,
            "fpr": fpr,
            "fnr": fnr,
        }
        ae_results.append(result)

        print(
            f"bottleneck={bottleneck_size}, percentile={percentile}: "
            f"Precision={precision:.4f}, Recall={recall:.4f}, "
            f"F1={f1:.4f}"
        )
        print("  Confusion matrix [[TP, FP], [FN, TN]]:")
        print("  Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]")
        print(np.array([[tp, fp], [fn, tn]]))
        for attack in sorted(np.unique(y_attack_ae)):
            attack_mask = y_evaluation_ae == attack
            detection_rate = predicted_attack[attack_mask].mean()
            print(f"  {attack} detection rate: {detection_rate:.4f}")

ae_results_df = pd.DataFrame(ae_results)
display(
    ae_results_df.sort_values("fnr", ascending=True).reset_index(drop=True)
)

# Select on validation data: prioritize recall, then control false alarms.
eligible_ae = ae_results_df[
    (ae_results_df["recall"] >= 0.90) & (ae_results_df["fpr"] <= 0.15)
]
if eligible_ae.empty:
    eligible_ae = ae_results_df[ae_results_df["fpr"] <= 0.15]
if eligible_ae.empty:
    eligible_ae = ae_results_df
best_ae_config = eligible_ae.sort_values(
    ["fnr", "fpr", "f1"], ascending=[True, True, False]
).iloc[0]
best_bottleneck_size = int(best_ae_config["bottleneck_size"])
best_ae_percentile = int(best_ae_config["threshold_percentile"])
best_autoencoder = autoencoder_models[best_bottleneck_size]
best_ae_threshold = float(best_ae_config["threshold"])

X_test_ae = X_test_scaled.astype(np.float32)
ae_test_reconstruction = best_autoencoder.predict(X_test_ae, verbose=0)
ae_test_scores = np.mean((X_test_ae - ae_test_reconstruction) ** 2, axis=1)
ae_test_predictions = ae_test_scores > best_ae_threshold
ae_test_truth = y_test != "benign"
ae_test_precision = precision_score(ae_test_truth, ae_test_predictions, zero_division=0)
ae_test_recall = recall_score(ae_test_truth, ae_test_predictions, zero_division=0)
ae_test_f1 = f1_score(ae_test_truth, ae_test_predictions, zero_division=0)
ae_tn, ae_fp, ae_fn, ae_tp = confusion_matrix(
    ae_test_truth, ae_test_predictions, labels=[False, True]
).ravel()
ae_test_fpr = ae_fp / (ae_fp + ae_tn)
ae_test_fnr = ae_fn / (ae_fn + ae_tp)
ae_test_roc_auc = roc_auc_score(ae_test_truth, ae_test_scores)
ae_test_pr_auc = average_precision_score(ae_test_truth, ae_test_scores)
print(
    f"Final autoencoder test: bottleneck={best_bottleneck_size}, "
    f"percentile={best_ae_percentile}, Precision={ae_test_precision:.4f}, "
    f"Recall={ae_test_recall:.4f}, F1={ae_test_f1:.4f}, "
    f"FPR={ae_test_fpr:.4f}, FNR={ae_test_fnr:.4f}, "
    f"ROC-AUC={ae_test_roc_auc:.4f}, PR-AUC={ae_test_pr_auc:.4f}"
)
print(np.array([[ae_tp, ae_fp], [ae_fn, ae_tn]]))
for attack in sorted(np.unique(y_test[y_test != "benign"])):
    attack_mask = y_test == attack
    print(f"  {attack} detection rate: {ae_test_predictions[attack_mask].mean():.4f}")

autoencoder_alerts_df = pd.DataFrame({
    "packet_id": packet_ids.iloc[index_test].to_numpy(),
    "true_label": y_test,
    "anomaly_score": ae_test_scores,
    "alert": ae_test_predictions,
})
autoencoder_alerts_df = autoencoder_alerts_df[
    autoencoder_alerts_df["alert"]
].reset_index(drop=True)
# Out:
# Bottleneck 2: trained for 50 epochs
# bottleneck=2, percentile=80: Precision=0.1287, Recall=0.8653, F1=0.2240
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[ 1028  6961]
#  [  160 31039]]
#   brute_force detection rate: 0.9578
#   ddos detection rate: 0.8861
#   dns_spoofing detection rate: 0.6218
#   dos detection rate: 0.9664
#   xss detection rate: 0.8950
# bottleneck=2, percentile=85: Precision=0.1553, Recall=0.7828, F1=0.2592
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  930  5057]
#  [  258 32943]]
#   brute_force detection rate: 0.9114
#   ddos detection rate: 0.7932
#   dns_spoofing detection rate: 0.5252
#   dos detection rate: 0.8992
#   xss detection rate: 0.7857
# bottleneck=2, percentile=90: Precision=0.1843, Recall=0.6187, F1=0.2841
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  735  3252]
#  [  453 34748]]
#   brute_force detection rate: 0.7173
#   ddos detection rate: 0.5148
#   dns_spoofing detection rate: 0.3950
#   dos detection rate: 0.7857
#   xss detection rate: 0.6807
# bottleneck=2, percentile=92: Precision=0.1825, Recall=0.4891, F1=0.2658
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  581  2602]
#  [  607 35398]]
#   brute_force detection rate: 0.5823
#   ddos detection rate: 0.3882
#   dns_spoofing detection rate: 0.2773
#   dos detection rate: 0.6008
#   xss detection rate: 0.5966
# bottleneck=2, percentile=95: Precision=0.1898, Recall=0.3199, F1=0.2382
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  380  1622]
#  [  808 36378]]
#   brute_force detection rate: 0.4008
#   ddos detection rate: 0.1857
#   dns_spoofing detection rate: 0.1597
#   dos detection rate: 0.2983
#   xss detection rate: 0.5546
# bottleneck=2, percentile=97: Precision=0.1764, Recall=0.1776, F1=0.1770
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  211   985]
#  [  977 37015]]
#   brute_force detection rate: 0.1730
#   ddos detection rate: 0.0928
#   dns_spoofing detection rate: 0.0462
#   dos detection rate: 0.1303
#   xss detection rate: 0.4454
# bottleneck=2, percentile=99: Precision=0.1550, Recall=0.0522, F1=0.0781
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   62   338]
#  [ 1126 37662]]
#   brute_force detection rate: 0.0591
#   ddos detection rate: 0.0042
#   dns_spoofing detection rate: 0.0168
#   dos detection rate: 0.0000
#   xss detection rate: 0.1807
# Bottleneck 4: trained for 50 epochs
# bottleneck=4, percentile=80: Precision=0.1236, Recall=0.8316, F1=0.2153
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  988  7004]
#  [  200 30996]]
#   brute_force detection rate: 0.8945
#   ddos detection rate: 0.8565
#   dns_spoofing detection rate: 0.7395
#   dos detection rate: 0.6975
#   xss detection rate: 0.9706
# bottleneck=4, percentile=85: Precision=0.1458, Recall=0.7323, F1=0.2431
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  870  5099]
#  [  318 32901]]
#   brute_force detection rate: 0.7806
#   ddos detection rate: 0.7089
#   dns_spoofing detection rate: 0.6218
#   dos detection rate: 0.6050
#   xss detection rate: 0.9454
# bottleneck=4, percentile=90: Precision=0.1786, Recall=0.5867, F1=0.2738
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  697  3206]
#  [  491 34794]]
#   brute_force detection rate: 0.6034
#   ddos detection rate: 0.4895
#   dns_spoofing detection rate: 0.4622
#   dos detection rate: 0.4916
#   xss detection rate: 0.8866
# bottleneck=4, percentile=92: Precision=0.1921, Recall=0.5076, F1=0.2787
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  603  2536]
#  [  585 35464]]
#   brute_force detection rate: 0.4726
#   ddos detection rate: 0.4093
#   dns_spoofing detection rate: 0.3950
#   dos detection rate: 0.4328
#   xss detection rate: 0.8277
# bottleneck=4, percentile=95: Precision=0.2210, Recall=0.3620, F1=0.2744
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  430  1516]
#  [  758 36484]]
#   brute_force detection rate: 0.2869
#   ddos detection rate: 0.2363
#   dns_spoofing detection rate: 0.3025
#   dos detection rate: 0.3025
#   xss detection rate: 0.6807
# bottleneck=4, percentile=97: Precision=0.2532, Recall=0.2492, F1=0.2512
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  296   873]
#  [  892 37127]]
#   brute_force detection rate: 0.1730
#   ddos detection rate: 0.1435
#   dns_spoofing detection rate: 0.1765
#   dos detection rate: 0.1849
#   xss detection rate: 0.5672
# bottleneck=4, percentile=99: Precision=0.2970, Recall=0.1010, F1=0.1508
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  120   284]
#  [ 1068 37716]]
#   brute_force detection rate: 0.0591
#   ddos detection rate: 0.0591
#   dns_spoofing detection rate: 0.0462
#   dos detection rate: 0.0546
#   xss detection rate: 0.2857
# Bottleneck 8: trained for 50 epochs
# bottleneck=8, percentile=80: Precision=0.1146, Recall=0.7786, F1=0.1998
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  925  7146]
#  [  263 30854]]
#   brute_force detection rate: 0.6667
#   ddos detection rate: 0.8608
#   dns_spoofing detection rate: 0.6303
#   dos detection rate: 0.8109
#   xss detection rate: 0.9244
# bottleneck=8, percentile=85: Precision=0.1354, Recall=0.6902, F1=0.2264
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  820  5235]
#  [  368 32765]]
#   brute_force detection rate: 0.6118
#   ddos detection rate: 0.7679
#   dns_spoofing detection rate: 0.5294
#   dos detection rate: 0.7227
#   xss detection rate: 0.8193
# bottleneck=8, percentile=90: Precision=0.1641, Recall=0.5606, F1=0.2539
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  666  3392]
#  [  522 34608]]
#   brute_force detection rate: 0.5527
#   ddos detection rate: 0.5654
#   dns_spoofing detection rate: 0.4244
#   dos detection rate: 0.6008
#   xss detection rate: 0.6597
# bottleneck=8, percentile=92: Precision=0.1786, Recall=0.4848, F1=0.2610
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  576  2649]
#  [  612 35351]]
#   brute_force detection rate: 0.5190
#   ddos detection rate: 0.4684
#   dns_spoofing detection rate: 0.3403
#   dos detection rate: 0.5042
#   xss detection rate: 0.5924
# bottleneck=8, percentile=95: Precision=0.2125, Recall=0.3628, F1=0.2680
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  431  1597]
#  [  757 36403]]
#   brute_force detection rate: 0.3586
#   ddos detection rate: 0.3122
#   dns_spoofing detection rate: 0.2689
#   dos detection rate: 0.3950
#   xss detection rate: 0.4790
# bottleneck=8, percentile=97: Precision=0.2192, Recall=0.2264, F1=0.2228
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  269   958]
#  [  919 37042]]
#   brute_force detection rate: 0.1646
#   ddos detection rate: 0.1392
#   dns_spoofing detection rate: 0.1849
#   dos detection rate: 0.2857
#   xss detection rate: 0.3571
# bottleneck=8, percentile=99: Precision=0.1990, Recall=0.0673, F1=0.1006
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[   80   322]
#  [ 1108 37678]]
#   brute_force detection rate: 0.0253
#   ddos detection rate: 0.0549
#   dns_spoofing detection rate: 0.0378
#   dos detection rate: 0.0504
#   xss detection rate: 0.1681
# Bottleneck 16: trained for 50 epochs
# bottleneck=16, percentile=80: Precision=0.1041, Recall=0.6961, F1=0.1812
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  827  7114]
#  [  361 30886]]
#   brute_force detection rate: 0.7257
#   ddos detection rate: 0.7932
#   dns_spoofing detection rate: 0.5210
#   dos detection rate: 0.7269
#   xss detection rate: 0.7143
# bottleneck=16, percentile=85: Precision=0.1162, Recall=0.5976, F1=0.1946
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  710  5399]
#  [  478 32601]]
#   brute_force detection rate: 0.6582
#   ddos detection rate: 0.6076
#   dns_spoofing detection rate: 0.4202
#   dos detection rate: 0.6429
#   xss detection rate: 0.6597
# bottleneck=16, percentile=90: Precision=0.1420, Recall=0.4815, F1=0.2193
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  572  3457]
#  [  616 34543]]
#   brute_force detection rate: 0.6076
#   ddos detection rate: 0.3966
#   dns_spoofing detection rate: 0.3151
#   dos detection rate: 0.5546
#   xss detection rate: 0.5336
# bottleneck=16, percentile=92: Precision=0.1581, Recall=0.4251, F1=0.2304
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  505  2690]
#  [  683 35310]]
#   brute_force detection rate: 0.5738
#   ddos detection rate: 0.2954
#   dns_spoofing detection rate: 0.2983
#   dos detection rate: 0.5084
#   xss detection rate: 0.4496
# bottleneck=16, percentile=95: Precision=0.2029, Recall=0.3409, F1=0.2544
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  405  1591]
#  [  783 36409]]
#   brute_force detection rate: 0.5190
#   ddos detection rate: 0.1772
#   dns_spoofing detection rate: 0.2605
#   dos detection rate: 0.3908
#   xss detection rate: 0.3571
# bottleneck=16, percentile=97: Precision=0.2511, Recall=0.2475, F1=0.2493
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  294   877]
#  [  894 37123]]
#   brute_force detection rate: 0.4262
#   ddos detection rate: 0.0549
#   dns_spoofing detection rate: 0.2059
#   dos detection rate: 0.2689
#   xss detection rate: 0.2815
# bottleneck=16, percentile=99: Precision=0.2875, Recall=0.0951, F1=0.1429
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  113   280]
#  [ 1075 37720]]
#   brute_force detection rate: 0.1181
#   ddos detection rate: 0.0169
#   dns_spoofing detection rate: 0.0966
#   dos detection rate: 0.0924
#   xss detection rate: 0.1513
# Bottleneck 32: trained for 50 epochs
# bottleneck=32, percentile=80: Precision=0.1132, Recall=0.7677, F1=0.1973
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  912  7144]
#  [  276 30856]]
#   brute_force detection rate: 0.7384
#   ddos detection rate: 0.9283
#   dns_spoofing detection rate: 0.6891
#   dos detection rate: 0.8067
#   xss detection rate: 0.6765
# bottleneck=32, percentile=85: Precision=0.1382, Recall=0.6928, F1=0.2304
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  823  5134]
#  [  365 32866]]
#   brute_force detection rate: 0.6835
#   ddos detection rate: 0.8523
#   dns_spoofing detection rate: 0.5630
#   dos detection rate: 0.7437
#   xss detection rate: 0.6218
# bottleneck=32, percentile=90: Precision=0.1717, Recall=0.5859, F1=0.2655
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  696  3358]
#  [  492 34642]]
#   brute_force detection rate: 0.5823
#   ddos detection rate: 0.7342
#   dns_spoofing detection rate: 0.4244
#   dos detection rate: 0.6681
#   xss detection rate: 0.5210
# bottleneck=32, percentile=92: Precision=0.1969, Recall=0.5345, F1=0.2878
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  635  2590]
#  [  553 35410]]
#   brute_force detection rate: 0.5527
#   ddos detection rate: 0.6456
#   dns_spoofing detection rate: 0.3529
#   dos detection rate: 0.6387
#   xss detection rate: 0.4832
# bottleneck=32, percentile=95: Precision=0.2513, Recall=0.4091, F1=0.3113
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  486  1448]
#  [  702 36552]]
#   brute_force detection rate: 0.4852
#   ddos detection rate: 0.4262
#   dns_spoofing detection rate: 0.2605
#   dos detection rate: 0.5042
#   xss detection rate: 0.3697
# bottleneck=32, percentile=97: Precision=0.3047, Recall=0.2988, F1=0.3017
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  355   810]
#  [  833 37190]]
#   brute_force detection rate: 0.4262
#   ddos detection rate: 0.2363
#   dns_spoofing detection rate: 0.1555
#   dos detection rate: 0.4244
#   xss detection rate: 0.2521
# bottleneck=32, percentile=99: Precision=0.3008, Recall=0.0909, F1=0.1396
#   Confusion matrix [[TP, FP], [FN, TN]]:
#   Rows: Predicted [Attack, Benign]; Columns: Actual [Attack, Benign]
# [[  108   251]
#  [ 1080 37749]]
#   brute_force detection rate: 0.0506
#   ddos detection rate: 0.0211
#   dns_spoofing detection rate: 0.0756
#   dos detection rate: 0.2017
#   xss detection rate: 0.1050
#     bottleneck_size  threshold_percentile  threshold  precision        f1  \
# 0                 2                    80   0.381475   0.128677  0.224038
# 1                 4                    80   0.232044   0.123624  0.215251
# 2                 2                    85   0.427923   0.155337  0.259233
# 3                 8                    80   0.154800   0.114608  0.199806
# 4                32                    80   0.039767   0.113208  0.197317
# 5                 4                    85   0.262973   0.145753  0.243119
# 6                16                    80   0.081616   0.104143  0.181181
# 7                32                    85   0.045926   0.138157  0.230371
# 8                 8                    85   0.176350   0.135425  0.226426
# 9                 2                    90   0.496788   0.184349  0.284058
# 10               16                    85   0.092848   0.116222  0.194601
# 11                4                    90   0.307771   0.178581  0.273817
# 12               32                    90   0.055074   0.171682  0.265548
# 13                8                    90   0.206855   0.164120  0.253908
# 14               32                    92   0.060418   0.196899  0.287786
# 15                4                    92   0.332775   0.192099  0.278715
# 16                2                    92   0.537314   0.182532  0.265843
# 17                8                    92   0.224572   0.178605  0.261047
# 18               16                    90   0.109574   0.141971  0.219283
# 19               16                    92   0.119238   0.158059  0.230436
# 20               32                    95   0.073849   0.251293  0.311339
# 21                8                    95   0.262467   0.212525  0.268035
# 22                4                    95   0.391286   0.220966  0.274410
# 23               16                    95   0.140967   0.202906  0.254397
# 24                2                    95   0.638470   0.189810  0.238245
# 25               32                    97   0.090686   0.304721  0.301742
# 26                4                    97   0.460127   0.253208  0.251167
# 27               16                    97   0.167751   0.251067  0.249258
# 28                8                    97   0.309571   0.219234  0.222774
# 29                2                    97   0.764015   0.176421  0.177013
# 30                4                    99   0.618462   0.297030  0.150754
# 31               16                    99   0.225834   0.287532  0.142948
# 32               32                    99   0.134054   0.300836  0.139625
# 33                8                    99   0.425388   0.199005  0.100629
# 34                2                    99   1.658502   0.155000  0.078086
#
#       recall       fpr       fnr
# 0   0.865320  0.183184  0.134680
# 1   0.831650  0.184316  0.168350
# 2   0.782828  0.133079  0.217172
# 3   0.778620  0.188053  0.221380
# 4   0.767677  0.188000  0.232323
# 5   0.732323  0.134184  0.267677
# 6   0.696128  0.187211  0.303872
# 7   0.692761  0.135105  0.307239
# 8   0.690236  0.137763  0.309764
# 9   0.618687  0.085579  0.381313
# 10  0.597643  0.142079  0.402357
# 11  0.586700  0.084368  0.413300
# 12  0.585859  0.088368  0.414141
# 13  0.560606  0.089263  0.439394
# 14  0.534512  0.068158  0.465488
# 15  0.507576  0.066737  0.492424
# 16  0.489057  0.068474  0.510943
# 17  0.484848  0.069711  0.515152
# 18  0.481481  0.090974  0.518519
# 19  0.425084  0.070789  0.574916
# 20  0.409091  0.038105  0.590909
# 21  0.362795  0.042026  0.637205
# 22  0.361953  0.039895  0.638047
# 23  0.340909  0.041868  0.659091
# 24  0.319865  0.042684  0.680135
# 25  0.298822  0.021316  0.701178
# 26  0.249158  0.022974  0.750842
# 27  0.247475  0.023079  0.752525
# 28  0.226431  0.025211  0.773569
# 29  0.177609  0.025921  0.822391
# 30  0.101010  0.007474  0.898990
# 31  0.095118  0.007368  0.904882
# 32  0.090909  0.006605  0.909091
# 33  0.067340  0.008474  0.932660
# 34  0.052189  0.008895  0.947811
# Final autoencoder test: bottleneck=2, percentile=85, Precision=0.1589, Recall=0.7862, F1=0.2644, FPR=0.1301, FNR=0.2138, ROC-AUC=0.8980, PR-AUC=0.1841
# [[  934  4944]
#  [  254 33056]]
#   brute_force detection rate: 0.9034
#   ddos detection rate: 0.7941
#   dns_spoofing detection rate: 0.5274
#   dos detection rate: 0.8992
#   xss detection rate: 0.8059

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 9))
axes = axes.ravel()

for axis, metric, title in zip(
    axes[:5],
    ["precision", "recall", "f1", "fpr", "fnr"],
    ["Precision", "Recall", "F1 Score", "False Positive Rate", "False Negative Rate"],
):
    for percentile in threshold_percentiles:
        subset = ae_results_df[
            ae_results_df["threshold_percentile"] == percentile
        ].sort_values("bottleneck_size")
        axis.plot(
            subset["bottleneck_size"],
            subset[metric],
            marker="o",
            label=f"Percentile {percentile}",
        )
    axis.set(title=title, xlabel="Bottleneck size", ylabel="Score")
    axis.set_xticks(bottleneck_sizes)
    axis.grid(alpha=0.3)
    axis.legend()

axes[5].axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Final Phase 2 Test Curves

# %%
from sklearn.metrics import roc_curve, precision_recall_curve

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

for name, scores in [
    ("K-means", kmeans_test_scores),
    ("Autoencoder", ae_test_scores),
]:
    fpr_curve, tpr_curve, _ = roc_curve(ae_test_truth, scores)
    curve_precision, curve_recall, _ = precision_recall_curve(ae_test_truth, scores)
    axes[0].plot(fpr_curve, tpr_curve, label=name)
    axes[1].plot(curve_recall, curve_precision, label=name)

axes[0].plot([0, 1], [0, 1], "--", color="gray")
axes[0].set(title="Test ROC Curve", xlabel="False Positive Rate", ylabel="True Positive Rate")
axes[1].set(title="Test Precision-Recall Curve", xlabel="Recall", ylabel="Precision")
for axis in axes:
    axis.grid(alpha=0.3)
    axis.legend()
plt.tight_layout()
plt.show()
